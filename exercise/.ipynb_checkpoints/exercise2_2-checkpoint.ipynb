# %%
import requests
from bs4 import BeautifulSoup

req = requests.get("http://media.daum.net/ranking/popular/")
html = req.text
bs = BeautifulSoup(html, 'html.parser')
titles = bs.select('ul.list_news2 > li > div.cont_thumb > strong > a')
comname = bs.select('div.cont_thumb > strong > span')

newstitles = []
newscomname = []

for dom in titles:
    newstitles.append(dom.text)
for dom in comname:
    newscomname.append(dom.text)
    

with open('C:/PyStexam/exercise/news.csv', "wt", encoding="utf-8") as f:
    f.write('newstitles,newscomname\n')  
    for i in range(len(newstitles)):
        f.write(newstitles[i]+","+newscomname[i]+'\n')

# %%
# 판다스 실습(3) 

import requests
from bs4 import BeautifulSoup
import pandas as pd

req = requests.get("http://media.daum.net/ranking/popular/")
html = req.text
bs = BeautifulSoup(html, 'html.parser')
titles = bs.select('ul.list_news2 > li > div.cont_thumb > strong > a')
comname = bs.select('div.cont_thumb > strong > span')

newstitles = []
newscomname = []

for dom in titles:
    newstitles.append(dom.text)
for dom in comname:
    newscomname.append(dom.text)
    
data = {"newstitles" : newstitles,
        "newscomname" : newscomname
       }

df = pd.DataFrame(data)
df.to_csv("../output/news.csv", index=False)
print(df)
display(df)
# Out:
#                                            newstitles newscomname
# 0    김진숙, 문 대통령에 편지 "옛 동지가 묻는다..언제까지 약자가 약자를 응원해야 하나"        경향신문
# 1              [단독]"머리 감기는데 가슴을.." 요양보호사 42%가 성희롱 당했다       머니투데이
# 2              이인영, 노벨평화상 수상 WFP에 "선정 축하..北 사업 적극 지원"         뉴스1
# 3                       '사상초유' 검찰총장까지 수사 받나..이성윤에 달렸다         뉴시스
# 4              [단독]로젠택배 40대 기사, '갑질' 호소 유서 남기고 극단적 선택         뉴스1
# 5                 뭘 먹었길래..중국 14살짜리 중학생 키가 무려 '2m21cm'        연합뉴스
# 6              100kg 넘는 아들 목 졸라 살해한 76세 노모에 징역 20년 구형        연합뉴스
# 7                   "추미애, 정치적 목적의 윤석열 망신주기"..법조계 한목소리         뉴스1
# 8            '국민의짐' 표현 "사과하라"..이재명 "국민의짐 진짜 안 되길 바란다"         뉴시스
# 9               "외국인 건보혜택 중국인이 71% 차지..5년반 동안 2조4천억원"        연합뉴스
# 10                  방금전 방송에서 나온 제품이 바로 홈쇼핑에..우연이 아니었다       머니투데이
# 11    [단독] "불투명 비말 칸막이 때문에 칠판이 안 보여요".. 초등학교 '깜깜이 수업'        서울신문
# 12            고창서 독감백신 맞은 70대 이튿날 사망.."인과관계 확인 중"(종합)        연합뉴스
# 13         "절도 이력 때문에 해사 불합격"..법원, 신원조회 위법 "불합격 취소하라"        중앙일보
# 14                "어려운 이웃에게 써달라" 대전 도마2동에 100만원 익명 기부        연합뉴스
# 15            21세 男 1명 1년간 3062회 병원 이용 최다..건보 3천만원 소요         뉴시스
# 16          1억 마세라티·5천 벤츠 몰며 서울 공공임대주택 거주 어떻게 가능?(종합)         뉴시스
# 17                      코로나에 다 망했다는데..'빵집'만 살아남은 이유는?       헤럴드경제
# 18                 국민의힘 "조국 딸 입학 취소 왜 안 하나" 부산대 국감 공세        연합뉴스
# 19                  소형 전기밥솥, 보온 기능에 차이..밥 딱딱하게 굳는 제품도         뉴스1
# 20                    전문직 소득 중 의사가 압도적 1위..변호사와 2배 격차        서울신문
# 21                 30대 남성의 수상한 기록, 2년여간 식욕억제제 2만정 타갔다       머니투데이
# 22                                '콩다방' 커피빈마저 매물로 나왔다       머니투데이
# 23               손흥민 토트넘 잔류시 최고 주급 유력..EPL 톱5 진입 가능성도      스포티비뉴스
# 24     '10조 빅딜' 이끈 최태원 SK회장의 승부수.. 현상유지만 하는 다른 그룹과 대조        조선비즈
# 25                  환자 저항에 검사하던 보건소 직원 옷 찢어져 '확진'(종합)         뉴시스
# 26             '불청' 김홍표 "교통사고로 4번 대수술, 일용직 조경에 대리운전도"         뉴스엔
# 27             '감사원 발표에 한숨' 월성원전 주민들 "경제성 없다는 이유 밝혀라"         뉴스1
# 28      '노는 언니' 박세리 "잘생긴 남자만 만났다" 10년지기 골프 후배들 폭로에 한탄         뉴스엔
# 29                           토트넘 '날벼락'..레알 레길론 재영입 고려      스포티비뉴스
# 30              "밥 굶는 아이 없도록"..전주 '엄마의 밥상'에 6년간 8억 쇄도        연합뉴스
# 31               [예천 육상] "누구야?!" 슈퍼유망주 '초미네이터' 등장에 흥분        에스티엔
# 32                    [단독] 고창서 70대 여성 독감 백신 접종 후 또 사망         더팩트
# 33                   '정경심 안대 퍼포먼스' 5명, 검찰송치..모욕 혐의 적용         뉴시스
# 34                            전국노래자랑 현장에서 포착한 대한민국 초상        연합뉴스
# 35           [현장연결] 질병청 "코로나 발생 안정세..이제 1단계 성적표 나올 것"      연합뉴스TV
# 36                   [단독] 참모들 부른 尹 "라임 비호세력 처단" 직접 썼다        국민일보
# 37              秋가 때리면 커지는 윤석열 존재감..'가족 수사' 이번엔 다를 수도         뉴스1
# 38              음주운전 사고부담금 최대 1억6500만원..전동킥보드도 차보험 보상       아시아경제
# 39                      "강원랜드 20초만에 털려..열쇠 분실 6년간 몰라"        서울신문
# 40                "내 출근룩은 치마에 하이힐"..여성옷 입는 60대 남성의 사연        서울신문
# 41                         "야당답지 못하다"..野원로들, 김종인에 쓴소리       헤럴드경제
# 42      이혜리 "'응팔' 5년만 박보검과 재회, 간식까지 챙겨줘 든든+감사"[직격인터뷰]         뉴스엔
# 43            손흥민, "영어 못하는 느낌 아니까".. '신입' 비니시우스 돕는 이유      스포탈코리아
# 44                         무리한 탈원전 정책에 무너진 韓 '원전 생태계'        조선비즈
# 45               '러시아 미녀' 라자레바, 차원이 다른 대박 외인..한국 왜 왔니        OSEN
# 46                    편의점 털려던 강도, 가게 갇혀 검거..종업원이 문 막아        동아일보
# 47  [단독] '밥심' 박해미 "전남편 음주사건 심경 고백 후련, 子 황성재 고마워 눈물...      엑스포츠뉴스
# 48            감사원 "월성1호기 경제성 평가 불합리"..조기폐쇄 판단은 안해(3보)         뉴스1
# 49              [단독] 중학생 의붓딸 4년간 '성적 학대'한 승려..구속영장 신청        한국경제
#                                            newstitles newscomname
# 0    김진숙, 문 대통령에 편지 "옛 동지가 묻는다..언제까지 약자가 약자를 응원해야 하나"        경향신문
# 1              [단독]"머리 감기는데 가슴을.." 요양보호사 42%가 성희롱 당했다       머니투데이
# 2              이인영, 노벨평화상 수상 WFP에 "선정 축하..北 사업 적극 지원"         뉴스1
# 3                       '사상초유' 검찰총장까지 수사 받나..이성윤에 달렸다         뉴시스
# 4              [단독]로젠택배 40대 기사, '갑질' 호소 유서 남기고 극단적 선택         뉴스1
# 5                 뭘 먹었길래..중국 14살짜리 중학생 키가 무려 '2m21cm'        연합뉴스
# 6              100kg 넘는 아들 목 졸라 살해한 76세 노모에 징역 20년 구형        연합뉴스
# 7                   "추미애, 정치적 목적의 윤석열 망신주기"..법조계 한목소리         뉴스1
# 8            '국민의짐' 표현 "사과하라"..이재명 "국민의짐 진짜 안 되길 바란다"         뉴시스
# 9               "외국인 건보혜택 중국인이 71% 차지..5년반 동안 2조4천억원"        연합뉴스
# 10                  방금전 방송에서 나온 제품이 바로 홈쇼핑에..우연이 아니었다       머니투데이
# 11    [단독] "불투명 비말 칸막이 때문에 칠판이 안 보여요".. 초등학교 '깜깜이 수업'        서울신문
# 12            고창서 독감백신 맞은 70대 이튿날 사망.."인과관계 확인 중"(종합)        연합뉴스
# 13         "절도 이력 때문에 해사 불합격"..법원, 신원조회 위법 "불합격 취소하라"        중앙일보
# 14                "어려운 이웃에게 써달라" 대전 도마2동에 100만원 익명 기부        연합뉴스
# 15            21세 男 1명 1년간 3062회 병원 이용 최다..건보 3천만원 소요         뉴시스
# 16          1억 마세라티·5천 벤츠 몰며 서울 공공임대주택 거주 어떻게 가능?(종합)         뉴시스
# 17                      코로나에 다 망했다는데..'빵집'만 살아남은 이유는?       헤럴드경제
# 18                 국민의힘 "조국 딸 입학 취소 왜 안 하나" 부산대 국감 공세        연합뉴스
# 19                  소형 전기밥솥, 보온 기능에 차이..밥 딱딱하게 굳는 제품도         뉴스1
# 20                    전문직 소득 중 의사가 압도적 1위..변호사와 2배 격차        서울신문
# 21                 30대 남성의 수상한 기록, 2년여간 식욕억제제 2만정 타갔다       머니투데이
# 22                                '콩다방' 커피빈마저 매물로 나왔다       머니투데이
# 23               손흥민 토트넘 잔류시 최고 주급 유력..EPL 톱5 진입 가능성도      스포티비뉴스
# 24     '10조 빅딜' 이끈 최태원 SK회장의 승부수.. 현상유지만 하는 다른 그룹과 대조        조선비즈
# 25                  환자 저항에 검사하던 보건소 직원 옷 찢어져 '확진'(종합)         뉴시스
# 26             '불청' 김홍표 "교통사고로 4번 대수술, 일용직 조경에 대리운전도"         뉴스엔
# 27             '감사원 발표에 한숨' 월성원전 주민들 "경제성 없다는 이유 밝혀라"         뉴스1
# 28      '노는 언니' 박세리 "잘생긴 남자만 만났다" 10년지기 골프 후배들 폭로에 한탄         뉴스엔
# 29                           토트넘 '날벼락'..레알 레길론 재영입 고려      스포티비뉴스
# 30              "밥 굶는 아이 없도록"..전주 '엄마의 밥상'에 6년간 8억 쇄도        연합뉴스
# 31               [예천 육상] "누구야?!" 슈퍼유망주 '초미네이터' 등장에 흥분        에스티엔
# 32                    [단독] 고창서 70대 여성 독감 백신 접종 후 또 사망         더팩트
# 33                   '정경심 안대 퍼포먼스' 5명, 검찰송치..모욕 혐의 적용         뉴시스
# 34                            전국노래자랑 현장에서 포착한 대한민국 초상        연합뉴스
# 35           [현장연결] 질병청 "코로나 발생 안정세..이제 1단계 성적표 나올 것"      연합뉴스TV
# 36                   [단독] 참모들 부른 尹 "라임 비호세력 처단" 직접 썼다        국민일보
# 37              秋가 때리면 커지는 윤석열 존재감..'가족 수사' 이번엔 다를 수도         뉴스1
# 38              음주운전 사고부담금 최대 1억6500만원..전동킥보드도 차보험 보상       아시아경제
# 39                      "강원랜드 20초만에 털려..열쇠 분실 6년간 몰라"        서울신문
# 40                "내 출근룩은 치마에 하이힐"..여성옷 입는 60대 남성의 사연        서울신문
# 41                         "야당답지 못하다"..野원로들, 김종인에 쓴소리       헤럴드경제
# 42      이혜리 "'응팔' 5년만 박보검과 재회, 간식까지 챙겨줘 든든+감사"[직격인터뷰]         뉴스엔
# 43            손흥민, "영어 못하는 느낌 아니까".. '신입' 비니시우스 돕는 이유      스포탈코리아
# 44                         무리한 탈원전 정책에 무너진 韓 '원전 생태계'        조선비즈
# 45               '러시아 미녀' 라자레바, 차원이 다른 대박 외인..한국 왜 왔니        OSEN
# 46                    편의점 털려던 강도, 가게 갇혀 검거..종업원이 문 막아        동아일보
# 47  [단독] '밥심' 박해미 "전남편 음주사건 심경 고백 후련, 子 황성재 고마워 눈물...      엑스포츠뉴스
# 48            감사원 "월성1호기 경제성 평가 불합리"..조기폐쇄 판단은 안해(3보)         뉴스1
# 49              [단독] 중학생 의붓딸 4년간 '성적 학대'한 승려..구속영장 신청        한국경제
