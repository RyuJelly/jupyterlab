# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %%
df = pd.read_csv("07_사회복지 종교.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "07_사회복지 종교"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['한국어교원', '3급', '토픽', '자격취득', '양성과정(이론+문풀', '양성과정', '이론강의', '한국어교원양성과정(3급)', '이론편', '한국어교원양성', '양성(한국어교원', '자격증', '대비반', '문제풀이']

# %%
comparelist = ['직업상담', '건강관리', '사회복지', '베이비시터', '아이돌보미', '전직지원']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('아이돌보미', '베이비시터', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/07.csv")
# Out:
#     Unnamed: 0                             과정명      학원명   기간     훈련비   정원  \
# 0            0  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  391500  500
# 1            1   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  286200  500
# 2            2             한국어교원양성과정(3급) -이론편-  한국이러닝협회   56  383800  500
# 3            3  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  430650  500
# 4            4   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  314820  500
# ..         ...                             ...      ...  ...     ...  ...
# 59          87  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
# 60          88  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
# 61          89   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500
# 62          91   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500
# 63          93  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
#
#      취업률   연령대          NCS분야    과정
# 0   26.0  53.0  04_교육 자연 사회과학  None
# 1   26.0   NaN  04_교육 자연 사회과학  None
# 2   26.0  51.0  04_교육 자연 사회과학  None
# 3   26.0  46.0  04_교육 자연 사회과학  None
# 4   26.0   NaN  04_교육 자연 사회과학  None
# ..   ...   ...            ...   ...
# 59  26.0   NaN  04_교육 자연 사회과학  None
# 60  26.0   NaN  04_교육 자연 사회과학  None
# 61  26.0   NaN  04_교육 자연 사회과학  None
# 62  26.0   NaN  04_교육 자연 사회과학  None
# 63  26.0   NaN  04_교육 자연 사회과학  None
#
# [64 rows x 10 columns]
# Unnamed: 0     0
# 과정명            0
# 학원명            0
# 기간             0
# 훈련비            0
# 정원             0
# 취업률            0
# 연령대           13
# NCS분야          0
# 과정            64
# dtype: int64
# 0 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 1 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 2 한국어교원양성과정(3급) -이론편-
# 3 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 4 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 5 한국어교원양성과정(3급) -이론편-
# 6 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 7 한국어교원양성과정(3급) -이론편-
# 8 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 9 한국어교원양성과정(3급) -이론편-
# 10 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 11 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 12 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 13 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 14 한국어교원양성과정(3급) -이론편-
# 15 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 16 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 17 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 18 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 19 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 20 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 21 한국어교원양성
# 22 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 23 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 24 한국어교원양성
# 25 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 26 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 27 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 28 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 29 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 30 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 31 한국어교원양성
# 32 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 33 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 34 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 35 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 36 한국어교원양성
# 37 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 38 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 39 한국어교원 자격증 대비반 (문제풀이)
# 40 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 41 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 42 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 43 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 44 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 45 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 46 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 47 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 48 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 49 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 50 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 51 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 52 한국어교원 양성(한국어교원 3급)
# 53 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 54 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 55 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 56 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 57 한국어교원 양성(한국어교원 3급)
# 58 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 59 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 60 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
# 61 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 62 [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)
# 63 [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)
