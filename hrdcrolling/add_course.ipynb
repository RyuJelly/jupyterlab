# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %% [markdown]
# ## 03_금융보험

# %%
df = pd.read_csv("03_금융보험.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "03_금융보험"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['합격', '은행FP(자산관리사)', '비즈니스반', '보험사무원', '총무', '양성과정', '보험총무사무원양성', '보험총무사무원']

# %%
comparelist = ['자산관리사', '보험사무원', '보험총무사무원']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('보험총무사무원', '보험사무원', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/03.csv")
# Out:
#     Unnamed: 0                       과정명         학원명  기간      훈련비   정원   취업률  \
# 0           11           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  42  1161380   20  93.8
# 1           18                   보험총무사무원  부천여성인력개발센터  40  1106080   20  64.3
# 2           27           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 3           28                 보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3
# 4           39           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 5           51           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 6           53  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 7           57  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 8           58  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 9           61  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 10          63           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 11          64                 보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3
# 12          65  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 13          67  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 14          70  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 15          71           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 16          72  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 17          75           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8
# 18          77  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 19          81  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 20          83  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 21          87  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1
# 22          88                 보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3
#
#      연령대    NCS분야     과정
# 0   36.0  03_금융보험  보험사무원
# 1   34.0  03_금융보험  보험사무원
# 2   31.0  03_금융보험  보험사무원
# 3   36.0  03_금융보험  보험사무원
# 4   35.0  03_금융보험  보험사무원
# 5   34.0  03_금융보험  보험사무원
# 6    NaN  03_금융보험  자산관리사
# 7   45.0  03_금융보험  자산관리사
# 8   36.0  03_금융보험  자산관리사
# 9   35.0  03_금융보험  자산관리사
# 10  33.0  03_금융보험  보험사무원
# 11  39.0  03_금융보험  보험사무원
# 12  33.0  03_금융보험  자산관리사
# 13  33.0  03_금융보험  자산관리사
# 14  29.0  03_금융보험  자산관리사
# 15  37.0  03_금융보험  보험사무원
# 16  33.0  03_금융보험  자산관리사
# 17   NaN  03_금융보험  보험사무원
# 18  42.0  03_금융보험  자산관리사
# 19   NaN  03_금융보험  자산관리사
# 20   NaN  03_금융보험  자산관리사
# 21   NaN  03_금융보험  자산관리사
# 22   NaN  03_금융보험  보험사무원
# Unnamed: 0    0
# 과정명           0
# 학원명           0
# 기간            0
# 훈련비           0
# 정원            0
# 취업률           0
# 연령대           6
# NCS분야         0
# 과정            0
# dtype: int64

# %% [markdown]
# ## 04_교육 자연 사회과학

# %%
df = pd.read_csv("04_교육 자연 사회과학.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "04_교육 자연 사회과학"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['한국어교원', '3급', '토픽', '자격취득', '양성과정(이론+문풀', '양성과정', '이론강의', '한국어교원양성과정(3급)', '이론편', '한국어교원양성', '양성(한국어교원', '자격증', '대비반', '문제풀이']

# %%
comparelist = ['한국어교원']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/04.csv")
# Out:
#     Unnamed: 0                             과정명      학원명   기간     훈련비   정원  \
# 0            0  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  391500  500
# 1            1   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  286200  500
# 2            2             한국어교원양성과정(3급) -이론편-  한국이러닝협회   56  383800  500
# 3            3  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  430650  500
# 4            4   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  314820  500
# ..         ...                             ...      ...  ...     ...  ...
# 59          87  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
# 60          88  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
# 61          89   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500
# 62          91   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500
# 63          93  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500
#
#      취업률   연령대          NCS분야     과정
# 0   26.0  53.0  04_교육 자연 사회과학  한국어교원
# 1   26.0   NaN  04_교육 자연 사회과학  한국어교원
# 2   26.0  51.0  04_교육 자연 사회과학  한국어교원
# 3   26.0  46.0  04_교육 자연 사회과학  한국어교원
# 4   26.0   NaN  04_교육 자연 사회과학  한국어교원
# ..   ...   ...            ...    ...
# 59  26.0   NaN  04_교육 자연 사회과학  한국어교원
# 60  26.0   NaN  04_교육 자연 사회과학  한국어교원
# 61  26.0   NaN  04_교육 자연 사회과학  한국어교원
# 62  26.0   NaN  04_교육 자연 사회과학  한국어교원
# 63  26.0   NaN  04_교육 자연 사회과학  한국어교원
#
# [64 rows x 10 columns]
# Unnamed: 0     0
# 과정명            0
# 학원명            0
# 기간             0
# 훈련비            0
# 정원             0
# 취업률            0
# 연령대           13
# NCS분야          0
# 과정             0
# dtype: int64

# %% [markdown]
# ## 05_법률 경찰 소방 교도 국방

# %%
df = pd.read_csv("05_법률 경찰 소방 교도 국방.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "05_법률 경찰 소방 교도 국방"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['회생파산', '법률사무관리직원취업과정', '송무법률사무취업과정', '법률사무원', '소장작성', '법률취업교육과정', '기초', '실무', '취업', '법률사무직원', '취업교육과정', '종합반', '소방설비', '산업', '소방설비기사', '산업기사', '법률사무원양성과정', '행정법률사무원취업양성과정', '전기분야', '소방시설관리사(필기+실기)취득', '대비', '자격취득반', '강제집행및형사소송실무', '기사기계필기', '기사전기필기', '양성', '필기', '이론', '기사전기필기실기', '기사기계필기실기', '[과정평가형]소방설비산업기사', '기계분야', 'AutoCAD2D+Inventor3D(캐드특허도면작성+ATC캐드마스터1급', '강제집행및회생파산,형사소송절차실무', '행정법률사무원', '실무양성과정', '(과정평가형)위험물산업기사_2020', '기사전기실기', '기사기계실기', '과정평가형', '소방설비산업기사(전기분야)', '자격취득과정', '(과정평가형)소방설비산업기사(전기)_2020', '자격취득반[실기+전기전공', '필기반', '(과정평가형)소방설비산업기사(기계)_2020', '문제풀이', '자격취득반(전기실기+전기전공']

# %%
comparelist = ['법률사무', '법률취업', '소방설비', '소방시설']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('법률사무', '법무', inplace=True)
df['과정'].replace('법률취업', '법무', inplace=True)

df['과정'].replace('소방설비', '소방', inplace=True)
df['과정'].replace('소방시설', '소방', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/05.csv")
# Out:
#      Unnamed: 0                   과정명              학원명  기간     훈련비   정원   취업률  \
# 0             0  소장작성 및 회생파산 법률취업교육과정       중앙법률사무교육학원  16  641280   60  76.7
# 1             1          법률사무관리직원취업과정           대한법률학원  20  935900   50  81.0
# 2             2   기초부터 실무까지! 법률사무원 취업  사단법인 한국에듀테크산업협회  56  302400  500  26.7
# 3             3     회생파산 및 송무법률사무취업과정           대한법률학원  15  701400   47  81.0
# 4             4        소방설비(산업)기사기계필기         중앙소방안전학원  24  447040   60  57.1
# ..          ...                   ...              ...  ..     ...  ...   ...
# 99          154  소장작성 및 회생파산 법률취업교육과정       중앙법률사무교육학원  16  641280   60  76.7
# 100         158          법률사무관리직원취업과정           대한법률학원  20  935900   50  81.0
# 101         160     회생파산 및 송무법률사무취업과정           대한법률학원  15  701400   47  81.0
# 102         165   법률사무직원 취업교육과정 (종합반)       중앙법률사무교육학원  23  921840   60  76.7
# 103         166         행정법률사무원취업양성과정        국민법률세무교육원  21  936320   30  61.8
#
#       연령대              NCS분야  과정
# 0    29.0  05_법률 경찰 소방 교도 국방  법무
# 1    31.0  05_법률 경찰 소방 교도 국방  법무
# 2    46.0  05_법률 경찰 소방 교도 국방  법무
# 3    31.0  05_법률 경찰 소방 교도 국방  법무
# 4    49.0  05_법률 경찰 소방 교도 국방  소방
# ..    ...                ...  ..
# 99   46.0  05_법률 경찰 소방 교도 국방  법무
# 100   NaN  05_법률 경찰 소방 교도 국방  법무
# 101   NaN  05_법률 경찰 소방 교도 국방  법무
# 102   NaN  05_법률 경찰 소방 교도 국방  법무
# 103  26.0  05_법률 경찰 소방 교도 국방  법무
#
# [104 rows x 10 columns]
# Unnamed: 0    0
# 과정명           0
# 학원명           0
# 기간            0
# 훈련비           0
# 정원            0
# 취업률           0
# 연령대           8
# NCS분야         0
# 과정            3
# dtype: int64
# 17 (과정평가형)위험물산업기사_2020
# 58 AutoCAD2D+Inventor3D(캐드특허도면작성+ATC캐드마스터1급)
# 71 AutoCAD2D+Inventor3D(캐드특허도면작성+ATC캐드마스터1급)

# %% [markdown]
# ## 06_보건 의료

# %%
df = pd.read_csv("06_보건 의료.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "06_보건 의료"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['요양보호사', '취득과정', '자격', '간호조무사', '자격증', '요양보호사자격증취득과정', '취득', '과정', '자격취득과정', '요양보호사자격취득과정', '국가자격증', '자격취득', '양성과정', '요양보호사자격증', '간호조무사자격취득과정', '자격증취득과정', '요양보호사자격증취득', '간호조무사자격증취득과정', '요양보호사양성과정', '실업자', '야간', '요양보호사자격취득', '사회복지사', '간호조무사자격증', '국가자격', '요양보호사국가자격증취득과정', '취득과정(비NCS', '표준', '병원코디네이터', '(주간', '주간과정', 'NCS요양보호사', '교육과정', '20', '요양보호사양성', '자격증취득', '국가자격증과정', '요양보호사자격증취득과정(이론+실기', '소지자반', '구직자', '일반반', '양성과정(자격증', '취득반', '소지자', '취업성공', '비적용', '취득과정(사회복지사', '국시대비', '국자자격', '상담실장양성과정', '취득과정(주간반', '양성', '요양보호사국가자격과정', '간호조무사자격증취득', '주간반', '취업', '신규', '2019-2', '요양보호사자격증과정', '오전', '신규자', '건강보험청구심사통합과정', '간호조무사자격취득', '간호조무사자격증취득과정A', '취업실무', '요양지원', '실업자과정(주간', '국가자격증취득', '&', '연계과정', '요양보호사1급자격증과정', '(국가공인)요양보호사', '과정(사회복지사', '보유자', '신규반', '요양보호사자격증취득&취업연계과정', '간호조무사자격', '야간반', '국', '기반', 'A+요양보호사자격증취득과정', '국가자격취득과정', '간호조무사국가자격증취득과정', '간호조무사자격취득및취업과정', '요양보호사취득과정', '요양보호사자격취득과정(신규,', '2020-1', '간병인', '취득과정(주간', '표준교육과정', '요양보호사지격증취득대비반', '취득(신규자과정', '간호조무사국가자격취득과정', '간호조무사자격취득과정(주간A', '요양보호사1급', '국제의료관광코디네이터', '사회복지사자격취득자', '상담실장', '의료서비스종합실무과정', '취득과정-사회복지사(국자자격', '면허', '이론', '실기', '일반', '특화', '국가자격증반', '사회복지사자격증반', '취득과정B', '취득과정(사회복지사자격증', '요양보호사국가자격취득', '양성과정(비NCS', '요양보호사자격증양성과정', '간호조무사자격취득과정(주간C', '요양보호사양', '국가자격소지자반', '자격증취득(주간', '자격소지반', '소지반', '요양보호사(NCS)', 'AA요양보호사자격취득', '요양보호사자격취득과정_간호조무사,물리치료사,작업치료사자격반', '요양보호사자격취득과정_사회복지사자격반', '병원특화간호조무사자격취득과정', '사회복지사자격증소지자', '간호조무사자격증과정', '교육과정(사회복지사', '요양보호사표준교육과정', 'ncs요양보호사국가자격증과정', '실무과정', '취득과정A', 'A+요양보호사자격취득', '적', '요양보호사국', '비NCS', '양성과정(간호조무사,물리치료사,작업치료사', '자격취득자', '표준교육', '주간', '적용', '간호조무사자격취득과정A', '간호조무사양성과정', '간호조무사국가자격과정', '병원실무', '자격증과정', '간호조무사자격취득과정B', '국비반', '자격증반', '자격취득과정_사회복지사자격증반', '간호조무사자격취득교육과정', '취득과정(간호조무사자격증', '소지', '취득(이론+실기', '간호조무사취득과정', '차', '클래스', '자격반', '성공취업', '간호조무사자격취득과정(주간B', '자격취득과정(자격증반', '간호조무사자격증취득과정B', '종합과정', '요양보호사국가자격증취득과정(요양보호사', '자격취득과정(비NCS', '요양원', '취득과정(주중', '주말반', '중장년층', '여성가장', '취약계층', '취득(일반', '요양보호사취득-국가자격', '요양보호사1급자격증취득과정', '자격증취득반', '간호조무사자격양성과정', '반', '[일반고특화]간호조무사자격취득및취업과정', '(일반고특화)간호조무사', '(일반고특화)', '간호조무사자격증취득과취업', '취득과정(주간B', 'NCS요양보호사국가자격증취득과정', '물리치료사', '작업치료사', '양성과정(간호조무사,작업치료사,물리치료사', 'NCS요양보호사자격취득과정', '신규자반', '구직과정', '간호조무사자격증취득반A', '과정A', '간호조무사자격취득과정(주간', '국가전문자격', '간호조무사국가자격', '요양보호사취득과정(사회복지사', '교육과정(간호조무사&물리치료사&작업치료사', '요양', '지원', '간병', '서비스', '간호조무사자격증취득반B', '요양병원', '요양보호사국가자격취득과정', '사회복지사반', '취득과정(신규', '자격취득과정(성남', '한누리', '요양보호사국가자격증취득', '간호조무사자격과정']

# %%
comparelist = ['요양보호사', '간호조무사', '사회복지사', '병원코디네이터', '의료서비스', '국제의료관광코디네이터', '건강보험']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/06.csv")
# Out:
#       Unnamed: 0                            과정명                           학원명  \
# 0              1                  요양보호사 자격 취득과정                    한성요양보호사교육원
# 1              2  요양보호사 국가 자격증 취득과정 (요양지원, 간병인)                    남동요양보호사교육원
# 2              3              요양보호사 국가 자격증 취득과정                    성심요양보호사교육원
# 3              4            요양보호사 자격 취득과정(비NCS)  세종고운간호전문학원(부설 세종고운요양보호사 교육원)
# 4              5                  요양보호사 자격 취득과정              홍성간호학원부설요양보호사교육원
# ...          ...                            ...                           ...
# 2975        4056                 A+요양보호사자격증취득과정                      평생비젼교육센터
# 2976        4057                요양보호사국가자격취득-주간반                    주은요양보호사교육원
# 2977        4059                   요양보호사자격증취득과정                    삼성요양보호사교육원
# 2978        4060                   병원코디네이터 실무과정              정연화의료서비스아카데미전문학원
# 2979        4061                 요양보호사 자격증 취득과정                  진해보금요양보호사교육원
#
#       기간     훈련비  정원   취업률   연령대     NCS분야       과정
# 0     30  480000  35  60.0  56.0  06_보건 의료    요양보호사
# 1     30  540000  40  51.5  53.0  06_보건 의료    요양보호사
# 2     36  600000  35  71.6  54.0  06_보건 의료    요양보호사
# 3     33  640080  30  64.7  55.0  06_보건 의료    요양보호사
# 4     30  641520  30  40.0  52.0  06_보건 의료    요양보호사
# ...   ..     ...  ..   ...   ...       ...      ...
# 2975  33  600000  26  57.1   NaN  06_보건 의료    요양보호사
# 2976  30  640800  32  55.7   NaN  06_보건 의료    요양보호사
# 2977  37  640800  30  57.3   NaN  06_보건 의료    요양보호사
# 2978  20  665160  30  63.6   NaN  06_보건 의료  병원코디네이터
# 2979  32  600000  40  45.7   NaN  06_보건 의료    요양보호사
#
# [2980 rows x 10 columns]
# Unnamed: 0      0
# 과정명             0
# 학원명             0
# 기간              0
# 훈련비             0
# 정원              0
# 취업률             0
# 연령대           213
# NCS분야           0
# 과정              0
# dtype: int64

# %% [markdown]
# ## 07_사회복지 종교

# %%
df = pd.read_csv("07_사회복지 종교.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "07_사회복지 종교"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['직업상담사2급', '직업상담사', '2급', '자격증', '필기', '취득과정', '1', '사회복지사', '양성', '완벽', '대비반(이론+문제풀', '실기', '원샷원킬', '한번', '사회복지사1급', '취득', '2차', '과정', '1차', '사회복지실천', '사회복지기초', '통합', '종합반(이론+문제풀', '자격', '베이비시터', '아이돌보미', '실기(필답형', '완성반', '사회복지정책과제', '핵심이론+문제풀', '종합반', '산모신생아', '건강관리사', '자격대비반_필기이론', '필기실기', '실기대비반', '필기대비반', '필기과정', '취득과정(1차,2차', '취득과정(1,2차', '취득과정(이론+실기', '와우패스', '자격(1차', '양성과정', '자격대비반_핵심이론+문제풀', '취득(필기+실기', '직업상담사2급자격증취득과정', '과정평가형', '국가기술자격', '통합반', '전직지원', '취득(1차+2차', '자격(2차', '실기과정', '자격증취득(1차+2차', '2급(1차+2차)자격증', '자격증취득과정(필기+실기', '직업상담사2급자격시험', '대비반', '과정(1,2차', '취득과정(필기,', '자격증취득', '취득과정(1차필기,', '2차실기', '취득(1,2차', '컨설턴트', '산모신생아건강관리사', 'NCS직업상담실무과정(직업상담사2급1차', '실무과정', '2020직업상담사2급취득(1차+2차', '취득(1차', '직업상담사(1차+2차', '자격증취득과정', '현장실무', '(2020)직업상담사2급취득(1차+2차', '직업상담사자격증(필기+실기', '자격증취득(2차', '취득과정(2차', '직업상담사2급취득(필기+실기', '【', '대비', '2020', '2020년', '과정평가형자격', '전문', '1차,2차(필기,실기)', '(2020)직업상담사취업상담전문', '취득과정(', '(1차+2차', '직업상담', '직업상담사2급(2차)자격증', '[과정평가형자격]직업상담사2급', '】자격증취득과정_직상2급(1차필기,2차실기', '자격증취득과정(1,2차통합', '자격취득', '(과정평가형자격)직업상담사2급취득과정', '생애설계', '심화과정', 'NCS직업상담실무과정(직업상담사2급2차', '자격]직업상담사2급', 'NCS직업상담사', '취득반', '(2020과정평가형)직업상담사2급', '직업상담사2급(1차,2차)', '】', '과정_직상2급', '2급_과정평가형자격', 'NCS직업상담사2급', '[과정평가형]직업상담사2급', '취득과정(필기+실기', '직업상담실무', '통합과정', '강사양성', '1급', '기반', '창업', '창직준비']

# %%
comparelist = ['직업상담', '건강관리', '사회복지', '베이비시터', '아이돌보미', '전직지원']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('아이돌보미', '베이비시터', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/07.csv")
# Out:
#      Unnamed: 0                            과정명          학원명  기간      훈련비   정원  \
# 0             0  직업상담사 2급 국가기술자격 취득과정(1,2차 통합)    씨앤씨직업상담학원  40  1028320   21
# 1             1             직업상담사 2급 취득(1차/2차)     중앙직업전문학교  50  1285400   20
# 2             2          직업상담사2급자격증취득과정(1차,2차)     현대직업전문학교  70  1349670   20
# 3             3                직업상담사자격증(필기+실기)  윤성회계캐드컴퓨터학원  50  1285400   20
# 4             6         원샷원킬! 직업상담사2급 필기실기 종합반      한국이러닝협회  56   424900  500
# ..          ...                            ...          ...  ..      ...  ...
# 526         745                     직업상담사 현장실무  서대문여성인력개발센터  16   411320   18
# 527         746              직업상담사2급 자격(1차 필기)   부산예일직업전문학교  26   655550   20
# 528         748           직업상담사2급 자격증취득(2차 실기)       양산직업학교  20   385620   20
# 529         749              직업상담사2급 취득(1차+2차)   중랑여성인력개발센터  46  1182560   20
# 530         750              직업상담사2급 취득(필기,실기)    북인천직업전문학교  35   893350   13
#
#       취업률   연령대       NCS분야    과정
# 0    40.0  32.0  07_사회복지 종교  직업상담
# 1    46.7  40.0  07_사회복지 종교  직업상담
# 2    49.1  32.0  07_사회복지 종교  직업상담
# 3    33.3  26.0  07_사회복지 종교  직업상담
# 4    32.5  35.0  07_사회복지 종교  직업상담
# ..    ...   ...         ...   ...
# 526  43.0  46.0  07_사회복지 종교  직업상담
# 527  34.1   NaN  07_사회복지 종교  직업상담
# 528  58.8   NaN  07_사회복지 종교  직업상담
# 529  30.4   NaN  07_사회복지 종교  직업상담
# 530  57.1   NaN  07_사회복지 종교  직업상담
#
# [531 rows x 10 columns]
# Unnamed: 0      0
# 과정명             0
# 학원명             0
# 기간              0
# 훈련비             0
# 정원              0
# 취업률             0
# 연령대           121
# NCS분야           0
# 과정              1
# dtype: int64
# 486 창업 및 창직준비 과정

# %% [markdown]
# ## 08_문화 예술 디자인 방송

# %%
df = pd.read_csv("08_문화 예술 디자인 방송.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "08_문화 예술 디자인 방송"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['양성과정', '양성', '활용', '게임', '반응형', '전문', '제작', '스마트', '디지털디자인', '실무', '디자인', '과정평가형', '과정', '웹디자', '시각디자인', '인디자인', '취득과정', '취득', '업무', '일러스트+포토샵', 'CS6', '[탑강]', 'UX디자', '7가지', '비밀', '영상편집&모션그래픽제작(프리미어,에펙', '미래', '예측', '빅데이터', '눈', '인포그래픽', '영상', '영상편집', '자격증', '3D', '웹디자인(웹퍼블리', '프리미어', '모바', '프로그래밍', '&', '취업과정', '제품디자인', '웹디자인(웹퍼블리셔)', 'PhotoShop(포토샵)', '한번', '끝내기', '웹디자인&웹퍼블리셔', '3D프린터', '그래픽', '콘텐츠', '포토샵&일러스트(기초부터실무)및', '취득과정(포토샵1급,일러스트1급', 'GTQ취득과정(포토샵,일러스트', '디자이너', '[플립드러닝]', '웹퍼블리셔)', '디지털', '일러스트CC', '디지털영상편집디자인(프리미어,에펙', '1', '웹퍼블리셔', '1급', '자격', '멀티미디어', '스케치업', '시각디자인(일러스트&포토샵', ')', '개발자', '웹디자인기능사', '편집', '일러스트,', '유튜브', '그래픽디자인', '시각영상편집디자인(일러스트,포토샵,프리미어,에펙,모션그래픽', '웹', '모션그래픽,', '시각편집(포토샵+일러스트+인디자인)GTQ그래픽기술자격증', '실내건축산업기사', '입문과정', '컴퓨터그래픽스운용기능사', '디지털디자인(웹디자이너,', '[핵심쏙쏙]GTQ', '자격증(포토샵+일러스트', '프론트앤드', '제작자', '그래픽디자인입문(포토샵,일러스트', '실기', '훈련', '영상제작', '캐드', '2', '그래픽디자인(포토샵+일러스트+인디자인+포트폴리오+그래픽스운용자격증', '시각디자인GTQ자격취득(일러스트&포토샵', '크리에이터', '앱', '웹디자인&웹퍼블리', '캐드실무능력평가(CAT)', '2급', '웹디자인&웹퍼블리셔(디자인&코딩)', '인테리', '디자인편집과영상편집&유튜브영상제작', '2020년', '프론트엔드', '구직자과정', '촬영', '영상편집(프리미어,에프터이펙트)', '캐릭터목업제작', '구직자', '웹퍼블리', '환경디자인', '맥스', '기', '[원격+집체훈련]', '모션', '편집(포토샵,', '애프터이펙트', '게임그래픽', '옥외광고', '3D그래픽', '디지털편집디자인(포토샵,일러스트', '웹표준', '영상편집(프리미어,', '(웹퍼블리셔)취업과정', '캐릭터', '3D프린팅', '광고콘텐츠영상제작(프리미어,애펙)+유튜브크리에이터', '취업전문과정', 'GTQ자격증(포토샵,일러스트', '실무과정', '그래픽디자이너양성(포토샵+일러스트+인디자인+포트폴리', '시각(영상)편집디자인(프리미어,', '애프터이펙트)', '프로그래머', '영상그래픽제작', '일러스트레이터', '3', '엔진', '3D프린터활용', '(시각디자인-GTQ취득)(포토샵1급,일러스트1급', '양성(포토샵+일러스트&그래픽실무', '멀티미디어콘텐츠제작', '자격취득', '웹&앱디자', '양성과정A', '반응형웹디자인&웹퍼블리', '에프터이펙트', '기획', '멀티미디어콘텐츠(촬영,', '/포토샵', '[웹디자인]', '포토샵&일러스트', 'GTQ1급', 'GTQ그래픽전문가(포토샵,', '일러스트)자격취득', '게임그래픽전문', '애프터이팩트)', '시각디자인-그래픽디자이너(포토샵,', '실내건축', '디지털디자인(멀티미디어웹)', '방송영상편집&모션', '크리에이팅', '영상편집(유투브동영상', '응용', '애펙)', '사진기능사취득과정', '광고영상편집&모션그래픽(포토,일러,인디,프리미어,에펙,C4D', '(게임콘텐츠제작)', '코딩', '디지털웹디자인(UI&UX', '영상기획', '신규구직자', '시각디자인(일러스트,포토샵', '사진기능사자격증', '인물', '제품사진촬영', '리터칭과정', '온라인게임', '광고홍보콘텐츠제작(포토샵,', '웹디자인(웹퍼블리셔)양성', '(HTML5,CSS3', '3D캐릭터애니메이션', '마', '영상편집(프리미어,에펙)&유튜브크리에이터', '3D프린터기반', '쇼핑몰구축', '웹디자인실무', '2D', '웹툰', '(프리미어,에프터이펙트,C4D)', '일러스트', '모션그래픽&영상편집(포토샵,프리미어,에프터이펙트', '전문가', '웹퍼블리셔(UIUX반응형웹디자인)전문', '게임콘텐츠&영상디자', '포토샵,', '웹디자인(웹퍼블리셔)양성과정(포토,일러,Html5', '기획자', '게임프로그래밍개발자', '일반', '만화콘텐츠(홍보웹툰,캐릭터)', '실내건축기사', '영상편집디자인', '웹디자인,', '기능사', '2D그래픽', '(멀티미디어콘텐츠제작)', '(프리미어,에프터이펙트)', '유튜브(YouTube)디지털', '영상편집(모션그래픽,프리미어,에펙', '편집(시각)디자인(포토샵+일러스트+GTQ자격증', '실무전문과정', '웹디자인&퍼블리', '그래픽실무(포토샵,일러스트', '3D프린팅운용', '디지털디자인(웹디자인,', '시각디자인(일러,포토,인디자인,GTQ자격증,컴퓨터그래픽스', '그래픽디자인(포토샵,', 'GTQ1급)기초+활용과정', '(2D원화,UI,3D', '인터렉티브', '접근성', '웹사이트', '앱디자인(웹퍼블리셔,jquery,', '/프론트엔드', '언리얼엔진게임개발자양성(게임기획&프로그래밍)', '디지털영상편집디자인', '모션그래픽제작(포토샵,일러스트,프리미어,에펙', '시각편집디자이너', '입문과정(포토샵,일러스트', '영상촬영', '영상그래픽', '맥스(3DMAX)', '디지털영상편집(프리미어,에펙', '디지털웹디자인양성과정(웹콘텐츠제작', '캐드(CAD),', '맥스(MAX))', '밸런스', '게임콘텐츠', '국기', '(웹퍼블리', '시각디자인(옥외광고)', '특화', '실무양성', '리소스', '자격증취득', '편집디자인', '환경인테리', '디자인(캐드,3DMAX', '실내건축디자인취업과정', '마야(MAYA)', '(웹디자인기능사', '영상편집디자인(프리미어,에펙)', '그래픽디자인실무&그래픽자격증취득(포토샵,일러스트', '반응형웹제작실무', '영상편집실무양성', '애프터이펙트(After', 'Effect),프리미어', '시각,편집디자인(포토샵,일러스트', '앱,', '국가기술자격증', '01', '시스템', '캐드마스터', '스마트기기UIUX앱&웹디자', '양성(웹퍼블리', '스마트콘텐츠', '디자인&영상편집(프리미어,애펙', '실내건축설계디자인[캐드(CAD),맥스(MAX)]', '웹디자인&웹퍼블리셔(Adobe', '포트폴리오', '시각디자인(포토샵,일러스트', '영상제작(영상편집,', '유튜브(Youtube)영상편집(프리미어,', '에펙', '실무자양성', '디자인과정', '(디지털디자인)스마트기기UIUX앱&웹디자', '디자인편집과영상그래픽편집', '/인디자인1급', '디지털디자인(웹&멀티미디어)', 'A1', '프론트앤드양성과정', '인테리어', '웹디자인(스마트기', '운영', '광고시각디자이너양성', '자격증(GTQ,', '컴그(실기))취득', '포토', '웹디자인(웹퍼블리셔)프론트앤드실무자양성_C', '멀티미디어&영상편집(모션그래픽,프리미어,에프터이펙트)양성과정', '게임콘텐츠제작', '웹개발자(웹디자', '5', '제품디자인(캐드,맥스,라이노)', '웹디자인(웹퍼블리셔)프론트앤드실무자양성', '시각디자인(2D그래픽,', '에프터이펙트)영상', '광고제작', '02', '프론트앤드실무자양성', '영상콘텐츠제작(프리미어,에펙,영상편집)', '제품설계제작(캐드,CAD,인벤터,MAX,포토샵', '디자인설계', '/3D프', '터', '멀티미디어콘텐츠제작&영상편집(프리미어,에프터이펙트,시네마4D', '양성(유니티3D', '디지털디자이너', '시각디자인산업기사', '2D,', '기반', '산업기사', '웹디자인', '멀티미디어콘텐츠제작(스마트', '앱&웹)', '운용', '제품응용모델링기능사', '쇼핑몰관리', '모션그래픽', '2020', '스마트UI', '양성A', '시각디자인(광고,편 ...

# %%
comparelist = ['사진', '공연기획',
               '디자인', '디자이너', '포토샵', '인포그래픽', '웹디자인', '웹사이트', '웹', '웹퍼블리셔', 'UX', 'UI', 'cad', 'CAD', '캐드', '실내',
               '게임', '영상', '콘텐츠', '일러스트', '웹툰', '애니메이션', '3D프린터', '3D프린팅', '그래픽']
# comparelist = ['웹디자인', '웹퍼블리셔', 'UX', 'UI', '그래픽',
#                '실내건축산업기사', '실내건축', '실내인테리어건축', '실내', 'cad', 'CAD', '캐드'
#                '환경디자인', '환경인테리어디자인', '실내환경디자인', '실내'
#                '제품디자인', '시각디자인', '시각디자이너', '시각', '공간디자인', '실내디자인'
#                '웹툰', '일러스트', '애니메이션', '유튜브', '쇼핑몰', '빅데이터', '3D프린터', '3D프린팅', '포토샵',
#                '멀티미디어', '영상미디어', '영상', '디지털디자인', '사진', '게임' ]
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('사진', '문화&예술', inplace=True)
df['과정'].replace('공연기획', '문화&예술', inplace=True)

df['과정'].replace('실내', '실내건축', inplace=True)

# df['과정'].replace('cad', 'CAD', inplace=True)
# df['과정'].replace('캐드', 'CAD', inplace=True)

df['과정'].replace('3D프린팅', '3D프린터', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/08.csv")
# Out:
#       Unnamed: 0                                        과정명          학원명   기간  \
# 0              0                            웹디자인&퍼블리셔 구직자과정   세잔IT직업전문학교  123
# 1              3            시각편집디자이너양성(포토샵+일러스트+인디자인+포트폴리오)    하우디자인캐드학원   48
# 2              5                       그래픽실무(포토샵,일러스트,인디자인)  배움회계캐드컴퓨터학원   30
# 3              6                              디자인편집과영상그래픽편집  배움회계캐드컴퓨터학원   50
# 4              7                환경디자인 실내건축전문가(캐드, 맥스, 스케치업)       이젠아카데미   75
# ...          ...                                        ...          ...  ...
# 1578        2371  [2020년 과정평가형]웹디자인기능사 취득과정(UX/UI디자인 웹퍼블리셔)   하이미디어컴퓨터학원   80
# 1579        2372                            3D프린터를 활용한 제품설계     인천직업전문학교  100
# 1580        2374                   (디지털디자인)웹퍼블리셔,UI/UX,웹디자인     영진직업전문학교   97
# 1581        2376   포토샵&일러스트(기초부터실무)및 GTQ 취득과정(포토샵1급,일러스트1급)     신영진컴퓨터학원   54
# 1582        2377                         게임 2D그래픽 디자이너 양성과정     서울게임아트학원  120
#
#           훈련비  정원   취업률   연령대            NCS분야     과정
# 0     4158060  30  94.1  25.0  08_문화 예술 디자인 방송    디자인
# 1     1067610  10  43.9  29.0  08_문화 예술 디자인 방송    디자인
# 2      674280  10  43.6   NaN  08_문화 예술 디자인 방송    디자인
# 3     1123800  10  43.6  29.0  08_문화 예술 디자인 방송    디자인
# 4     3371400  20  66.7  25.0  08_문화 예술 디자인 방송    디자인
# ...       ...  ..   ...   ...              ...    ...
# 1578  3539400  22  71.4  22.0  08_문화 예술 디자인 방송    디자인
# 1579  3933300  20  63.8   NaN  08_문화 예술 디자인 방송  3D프린터
# 1580  4184840  25  83.6   NaN  08_문화 예술 디자인 방송    디자인
# 1581   899040  10  49.0   NaN  08_문화 예술 디자인 방송    포토샵
# 1582  2243160  20  51.1   NaN  08_문화 예술 디자인 방송   디자이너
#
# [1583 rows x 10 columns]
# Unnamed: 0      0
# 과정명             0
# 학원명             0
# 기간              0
# 훈련비             0
# 정원              0
# 취업률             0
# 연령대           310
# NCS분야           0
# 과정             12
# dtype: int64
# 15 IT기기 활용을 위한 e-Book과 app-Book
# 47 IT기기 활용을 위한 e-Book과 app-Book
# 96 IT기기 활용을 위한 e-Book과 app-Book
# 147 IT기기 활용을 위한 e-Book과 app-Book
# 198 IT기기 활용을 위한 e-Book과 app-Book
# 252 IT기기 활용을 위한 e-Book과 app-Book
# 317 IT기기 활용을 위한 e-Book과 app-Book
# 398 (일반고특화)제품응용모델링기능사 자격증 취득 및 실무 과정
# 656 후반작업관리전문가(편집, 2D, 3D)
# 899 영화VFX 마야이펙트 취업과정
# 921 기업맞춤형 시각ㆍ광고 크리에이터 양성과정
# 1374 (과정평가형)제품응용모델링기능사 자격증취득과정(A)

# %% [markdown]
# ## 09_운전 운송

# %%
df = pd.read_csv("09_운전 운송.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "09_운전 운송"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['항공사지상직', '초경량비행장치(드론)', '조종자', '자격증', '취득과정', '양성과정', '일반고특화_영상촬영드론조종및항공드론정비융합과정', '교관', '영상촬영용', '드론조종', '교관양성과정']

# %%
comparelist = ['드론', '항공사지상직']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/09.csv")
# Out:
#     Unnamed: 0                            과정명           학원명   기간      훈련비  정원  \
# 0            2  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 1            3  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 2           10       초경량비행장치(드론) 조종자 자격증 취득과정       더조은아카데미   19  2001080   8
# 3           16  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 4           17       초경량비행장치(드론) 조종자 자격증 취득과정       더조은아카데미   20  2001080   8
# 5           22      일반고특화_영상촬영드론조종및항공드론정비융합과정  청연항공과학직업전문학교  176  8084520  30
# 6           25  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 7           35  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 8           54  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 9           58  초경량비행장치(드론) 조종자 자격증 및 교관 양성과정       더조은아카데미   45  3501940   8
# 10          65                영상촬영용 드론조종 양성과정      다옴직업전문학교  143  7126000  24
# 11          68  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 12          82  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   18  1351260  16
# 13          90  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   20  1351260  16
# 14         107       초경량비행장치(드론) 조종자 자격증 취득과정       더조은아카데미   20  2500000   8
# 15         110  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   20  1351260  16
# 16         121  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   20  1351260  16
# 17         140       초경량비행장치(드론) 조종자 자격증 취득과정       더조은아카데미   20  2500000   8
# 18         142         초경량비행장치(드론) 조종자 교관양성과정       더조은아카데미   50  4000000   8
# 19         144  항공사지상직 체크인카운터/예약발권과정(DCS/CRS)         코세아학원   20  1351260  16
#
#      취업률   연령대     NCS분야      과정
# 0   51.8  24.0  09_운전 운송  항공사지상직
# 1   51.8  24.0  09_운전 운송  항공사지상직
# 2   41.2  46.0  09_운전 운송      드론
# 3   51.8  25.0  09_운전 운송  항공사지상직
# 4   41.2   NaN  09_운전 운송      드론
# 5   56.9   NaN  09_운전 운송      드론
# 6   51.8  23.0  09_운전 운송  항공사지상직
# 7   51.8  26.0  09_운전 운송  항공사지상직
# 8   51.8  26.0  09_운전 운송  항공사지상직
# 9   41.2  39.0  09_운전 운송      드론
# 10  84.6  42.0  09_운전 운송      드론
# 11  51.8  25.0  09_운전 운송  항공사지상직
# 12  51.8  25.0  09_운전 운송  항공사지상직
# 13  51.8  23.0  09_운전 운송  항공사지상직
# 14  41.2  43.0  09_운전 운송      드론
# 15  51.8  23.0  09_운전 운송  항공사지상직
# 16  51.8  25.0  09_운전 운송  항공사지상직
# 17  41.2   NaN  09_운전 운송      드론
# 18  41.2   NaN  09_운전 운송      드론
# 19  51.8   NaN  09_운전 운송  항공사지상직
# Unnamed: 0    0
# 과정명           0
# 학원명           0
# 기간            0
# 훈련비           0
# 정원            0
# 취업률           0
# 연령대           5
# NCS분야         0
# 과정            0
# dtype: int64

# %% [markdown]
# ## 10_영업판매

# %%
df = pd.read_csv("10_영업판매.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df['NCS분야'] = "10_영업판매"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['쇼핑몰', '양성', '구축', '오픈마켓', '과정', ')판매', '판매자', '양성과정', '제작', '판매', '쇼핑몰(오픈마켓,스마트스토어)', '운영', '전자상거래', '홈페이지', '마케팅', '글로벌셀러(이베이,', '아마존)', '카페24', '네이버', '해외', '인터넷', '쇼핑몰(아마존)', '기초', '실무', '상품사진', '촬영', '상세페이지(이미지)', '리터칭', '온라인', '활용', '상세페이지', '마케팅(온라', '마케팅1', '쇼핑몰(카페24+오픈마켓+스마트스토어)', '관리자양성', '운영(스마트스토어,', '옥션,', '지마켓', '웹디자인&쇼핑몰', '쇼핑몰디자', '구축운영(포토샵,', '사진촬영', '웹디자', '사이트', '쇼핑몰(카페24)', '개인쇼핑몰', '/B2B', '셀러']

# %%
comparelist = ['쇼핑몰', '오픈마켓', '스마트스토어', '글로벌셀러']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
df['과정'].replace('쇼핑몰', 'e-비지니스', inplace=True)
df['과정'].replace('오픈마켓', 'e-비지니스', inplace=True)
df['과정'].replace('스마트스토어', 'e-비지니스', inplace=True)
df['과정'].replace('글로벌셀러', 'e-비지니스', inplace=True)
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/10.csv")
# Out:
#     Unnamed: 0                               과정명         학원명  기간      훈련비  정원  \
# 0            0                        네이버 쇼핑몰 제작   부산나래디자인학원  38  1035600  10
# 1            1   쇼핑몰(오픈마켓/스마트스토어/스토어팜/B2B)판매자 양성    영등포평생교육원  50  1380800  20
# 2           13          해외 인터넷 쇼핑몰(아마존) 판매 기초 실무  씨이오창조인재개발원  50  1380800  15
# 3           14             전자상거래 쇼핑몰 홈페이지 사이트 구축     열린컴퓨터학원  40  1380800  10
# 4           27         쇼핑몰(오픈마켓,스마트스토어) 판매자 양성과정  서울IT직업전문학교  40  1380800  20
# ..         ...                               ...         ...  ..      ...  ..
# 68         349            전자상거래 오픈마켓 쇼핑몰 홈페이지 구축     열린컴퓨터학원  40  1380800  10
# 69         350  온라인 오픈마켓 판매와 운영(스마트스토어, 옥션, 지마켓)      뉴컴퓨터학원  28   952750  10
# 70         362              카페24로 온라인 쇼핑몰 구축과 운영      뉴컴퓨터학원  46   952750  10
# 71         371          쇼핑몰(오픈마켓,스마트스토어) 셀러 양성과정  서울IT직업전문학교  40  1380800  20
# 72         372   쇼핑몰(오픈마켓/스마트스토어/스토어팜/B2B)판매자 양성    영등포평생교육원  50  1380800  20
#
#      취업률   연령대    NCS분야      과정
# 0   70.2  48.0  10_영업판매  e-비지니스
# 1   42.4  48.0  10_영업판매  e-비지니스
# 2   53.3  41.0  10_영업판매  e-비지니스
# 3   43.3  35.0  10_영업판매  e-비지니스
# 4   43.9  44.0  10_영업판매  e-비지니스
# ..   ...   ...      ...     ...
# 68  43.3   NaN  10_영업판매  e-비지니스
# 69  50.0   NaN  10_영업판매  e-비지니스
# 70  50.0   NaN  10_영업판매  e-비지니스
# 71  43.9   NaN  10_영업판매  e-비지니스
# 72  42.4   NaN  10_영업판매  e-비지니스
#
# [73 rows x 10 columns]
# Unnamed: 0    0
# 과정명           0
# 학원명           0
# 기간            0
# 훈련비           0
# 정원            0
# 취업률           0
# 연령대           8
# NCS분야         0
# 과정            0
# dtype: int64
