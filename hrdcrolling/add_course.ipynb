# %% [markdown]
# ## 03_금융보험

# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re
df = pd.read_csv("03_금융보험.csv")
df.dropna(subset=['취업률'], inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
indexlist = []
for i in range(len(df)):
    indexlist.append(i)
# df1 = df.reindex(indexlist) <- 이거 왜 안 됌?
df['index'] = indexlist
df = df.set_index('index')
df['NCS분야'] = "03_금융보험"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)
df_a = re.sub('양성', '', df_a)
df_a = re.sub('실무자', '', df_a)
# t = Okt()
# tokens_ko = t.nouns(df_a)

# ko_ = nltk.Text(tokens_ko)  
# ko_.vocab()
# freq_dic = dict(ko_.vocab())
# print(freq_dic)

hannanum = Hannanum()
    
t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
[freq_dic.pop(key) for key in ['합격', '과정', '총무', '비즈니스반']]
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

print(sortedDict)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)

# %%
courselist = []
for i in range(len(df)) :
#     df_c[i] = re.sub("['양성', '실무자']", '', df_c[i])
    df_c[i] = re.sub('양성', '', df_c[i])
    df_c[i] = re.sub('실무자', '', df_c[i])
    tokens = hannanum.nouns(df_c[i])
    tx = nltk.Text(tokens)
    freq_dic = dict(tx.vocab())
    [freq_dic.pop(key, None) for key in ['합격', '과정', '총무', '비즈니스반']]
    fre = list(freq_dic.keys())
    fre = fre[0]
    if fre in sortlist:
        courselist.append(fre)
    else:
        courselist.append('None')

df['과정'] = courselist
display(df)

df.to_csv("preprocessing/03_금융보험.csv")

# %% [markdown]
# ## 04_교육 자연 사회과학

# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re
df = pd.read_csv("04_교육 자연 사회과학.csv")
df.dropna(subset=['취업률'], inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
indexlist = []
for i in range(len(df)):
    indexlist.append(i)
# df1 = df.reindex(indexlist) <- 이거 왜 안 됌?
df['index'] = indexlist
df = df.set_index('index')
df['NCS분야'] = "04_교육 자연 사회과학"
display(df)

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)
df_a = re.sub('양성과정', '', df_a)
df_a = re.sub('양성', '', df_a)
df_a = re.sub('3급', '', df_a)
df_a = re.sub('[(]', '', df_a)
# t = Okt()
# tokens_ko = t.nouns(df_a)

# ko_ = nltk.Text(tokens_ko)  
# ko_.vocab()
# freq_dic = dict(ko_.vocab())
# print(freq_dic)

hannanum = Hannanum()
    
t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
[freq_dic.pop(key) for key in ['자격취득', '자격증', '문제풀이', '대비반', '토픽', '이론+문풀', '이론강의', '이론편']]
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

print(sortedDict)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)

# %%
courselist = []
for i in range(len(df)) :
    df_c[i] = re.sub('양성과정', '', df_c[i])
    df_c[i] = re.sub('양성', '', df_c[i])
    df_c[i] = re.sub('3급', '', df_c[i])
    df_c[i] = re.sub('[(]', '', df_c[i])
    tokens = hannanum.nouns(df_c[i])
    tx = nltk.Text(tokens)
    freq_dic = dict(tx.vocab())
    [freq_dic.pop(key, None) for key in ['자격취득', '자격증', '문제풀이', '대비반', '토픽', '이론+문풀', '이론강의', '이론편']]
    fre = list(freq_dic.keys())
    fre = fre[0]
    if fre in sortlist:
        courselist.append(fre)
    else:
        courselist.append('None')

df['과정'] = courselist
display(df)

df.to_csv("preprocessing/04_교육 자연 사회과학.csv")

# %% [markdown]
# ## 05_법률 경찰 소방 교도 국방

# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re
df = pd.read_csv("05_법률 경찰 소방 교도 국방.csv")
df.dropna(subset=['취업률'], inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
indexlist = []
for i in range(len(df)):
    indexlist.append(i)
# df1 = df.reindex(indexlist) <- 이거 왜 안 됌?
df['index'] = indexlist
df = df.set_index('index')
df['NCS분야'] = "05_법률 경찰 소방 교도 국방"
display(df)

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)
df_a = re.sub('과정', '', df_a)
df_a = re.sub('취업', '', df_a)
df_a = re.sub('양성', '', df_a)
df_a = re.sub('평가형', '', df_a)
df_a = re.sub('기초', '', df_a)
df_a = re.sub('실무', '', df_a)
df_a = re.sub("['(', ')']", '', df_a)

# t = Okt()
# tokens_ko = t.nouns(df_a)

# ko_ = nltk.Text(tokens_ko)  
# ko_.vocab()
# freq_dic = dict(ko_.vocab())
# print(freq_dic)

hannanum = Hannanum()
    
t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
[freq_dic.pop(key) for key in ['부터까', '문제풀이', '전기전공']]
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

print(sortedDict)
print('\n')
sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
#                         과정명              학원명  기간     훈련비   정원   취업률   연령대  \
# index
# 0      소장작성 및 회생파산 법률취업교육과정       중앙법률사무교육학원  16  641280   60  76.7  29.0
# 1              법률사무관리직원취업과정           대한법률학원  20  935900   50  81.0  31.0
# 2       기초부터 실무까지! 법률사무원 취업  사단법인 한국에듀테크산업협회  56  302400  500  26.7  46.0
# 3         회생파산 및 송무법률사무취업과정           대한법률학원  15  701400   47  81.0  31.0
# 4            소방설비(산업)기사기계필기         중앙소방안전학원  24  447040   60  57.1  49.0
# ...                     ...              ...  ..     ...  ...   ...   ...
# 99     소장작성 및 회생파산 법률취업교육과정       중앙법률사무교육학원  16  641280   60  76.7  46.0
# 100            법률사무관리직원취업과정           대한법률학원  20  935900   50  81.0   NaN
# 101       회생파산 및 송무법률사무취업과정           대한법률학원  15  701400   47  81.0   NaN
# 102     법률사무직원 취업교육과정 (종합반)       중앙법률사무교육학원  23  921840   60  76.7   NaN
# 103           행정법률사무원취업양성과정        국민법률세무교육원  21  936320   30  61.8  26.0
#
#                    NCS분야
# index
# 0      05_법률 경찰 소방 교도 국방
# 1      05_법률 경찰 소방 교도 국방
# 2      05_법률 경찰 소방 교도 국방
# 3      05_법률 경찰 소방 교도 국방
# 4      05_법률 경찰 소방 교도 국방
# ...                  ...
# 99     05_법률 경찰 소방 교도 국방
# 100    05_법률 경찰 소방 교도 국방
# 101    05_법률 경찰 소방 교도 국방
# 102    05_법률 경찰 소방 교도 국방
# 103    05_법률 경찰 소방 교도 국방
#
# [104 rows x 8 columns]
# [('법률사무관리직원', 15), ('회생파산및송무법률사무', 15), ('법률사무원', 13), ('소장작성및회생파산법률교육', 11), ('법률사무직원교육종합반', 11), ('행정법률사무원', 6), ('소방시설관리사필기+실기취득대비', 4), ('강제집행및형사소송법률사무원', 3), ('소방설비산업기사기계필기', 2), ('소방설비산업기사전기필기', 2), ('이론', 2), ('소방설비산업기사전기필기실기', 2), ('소방설비산업기사기계필기실기', 2), ('AutoCAD2D+Inventor3D캐드특허도면작성+ATC캐드마스터1급', 2), ('강제집행및회생파산형사소송절차법률사무원', 2), ('전기분야', 1), ('위험물산업기사_2020', 1), ('소방설비산업기사전기실기', 1), ('소방설비산업기사기계실기', 1), ('소방설비산업기사전기분야자격취득', 1), ('소방설비산업기사전기_2020', 1), ('[실기+전기전공', 1), ('소방설비산업기사전기분야', 1), ('소방설비산업기사기계분야', 1), ('소방설비산업기사기계_2020', 1)]
#
#
# ['법률사무관리직원', '회생파산및송무법률사무', '법률사무원', '소장작성및회생파산법률교육', '법률사무직원교육종합반', '행정법률사무원', '소방시설관리사필기+실기취득대비', '강제집행및형사소송법률사무원', '소방설비산업기사기계필기', '소방설비산업기사전기필기', '이론', '소방설비산업기사전기필기실기', '소방설비산업기사기계필기실기', 'AutoCAD2D+Inventor3D캐드특허도면작성+ATC캐드마스터1급', '강제집행및회생파산형사소송절차법률사무원', '전기분야', '위험물산업기사_2020', '소방설비산업기사전기실기', '소방설비산업기사기계실기', '소방설비산업기사전기분야자격취득', '소방설비산업기사전기_2020', '[실기+전기전공', '소방설비산업기사전기분야', '소방설비산업기사기계분야', '소방설비산업기사기계_2020']
