# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %%
df = pd.read_csv("06_보건 의료.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['NCS'] = "06_보건의료"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['요양보호사', '취득과정', '자격', '간호조무사', '자격증', '요양보호사자격증취득과정', '취득', '과정', '자격취득과정', '요양보호사자격취득과정', '국가자격증', '자격취득', '양성과정', '간호조무사자격취득과정', '요양보호사자격증', '요양보호사자격증취득', '자격증취득과정', '간호조무사자격증취득과정', '실업자', '요양보호사자격취득', '요양보호사양성과정', '야간', '사회복지사', '간호조무사자격증', '국가자격', '취득과정(비NCS', '요양보호사국가자격증취득과정', '표준', '병원코디네이터', '(주간', '주간과정', 'NCS요양보호사', '교육과정', '20', '요양보호사양성', '자격증취득', '국가자격증과정', '요양보호사자격증취득과정(이론+실기', '소지자반', '구직자', '일반반', '양성과정(자격증', '취득반', '소지자', '취업성공', '비적용', '취득과정(사회복지사', '국시대비', '국자자격', '상담실장양성과정', '양성', '취득과정(주간반', '요양보호사국가자격과정', '간호조무사자격증취득', '주간반', '취업', '신규', '2019-2', '요양보호사자격증과정', '오전', '신규자', '신규반', '건강보험청구심사통합과정', '간호조무사자격취득', '간호조무사자격증취득과정A', '취업실무', '요양지원', '국가자격증취득', '&', '연계과정', '실업자과정(주간', '(국가공인)요양보호사', '요양보호사1급자격증과정', '과정(사회복지사', '보유자', '요양보호사자격증취득&취업연계과정', '간호조무사자격', '야간반', '국', '기반', 'A+요양보호사자격증취득과정', '국가자격취득과정', '간호조무사국가자격증취득과정', '간호조무사자격취득및취업과정', '요양보호사취득과정', '요양보호사자격취득과정(신규,', '2020-1', '취득과정(주간', '간병인', '표준교육과정', '요양보호사지격증취득대비반', '취득(신규자과정', '간호조무사국가자격취득과정', '간호조무사자격취득과정(주간A', '요양보호사1급', '사회복지사자격취득자', '상담실장', '의료서비스종합실무과정', '취득과정-사회복지사(국자자격', '면허', '이론', '실기', '일반', '특화', '국가자격증반', '사회복지사자격증반', '취득과정B', '취득과정(사회복지사자격증', '요양보호사국가자격취득', '양성과정(비NCS', '요양보호사자격증양성과정', '요양보호사양', '국가자격소지자반', '자격소지반', '자격증취득(주간', '소지반', '요양보호사(NCS)', 'AA요양보호사자격취득', '요양보호사자격취득과정_사회복지사자격반', '요양보호사자격취득과정_간호조무사,물리치료사,작업치료사자격반', '병원특화간호조무사자격취득과정', '사회복지사자격증소지자', '간호조무사자격증과정', '교육과정(사회복지사', '국제의료관광코디네이터', 'ncs요양보호사국가자격증과정', '실무과정', '취득과정A', 'A+요양보호사자격취득', '간호조무사자격취득과정(주간C', '요양보호사국', '적', '비NCS', '양성과정(간호조무사,물리치료사,작업치료사', '자격취득자', '표준교육', '주간', '적용', '간호조무사자격취득과정A', '간호조무사양성과정', '간호조무사국가자격과정', '병원실무', '자격증과정', '간호조무사자격취득과정B', '국비반', '자격증반', '자격취득과정_사회복지사자격증반', '간호조무사자격취득교육과정', '취득과정(간호조무사자격증', '소지', '간호조무사취득과정', '취득(이론+실기', '성공취업', '간호조무사자격취득과정(주간B', '자격취득과정(자격증반', '요양보호사표준교육과정', '간호조무사자격증취득과정B', '구직과정', '종합과정', '요양보호사국가자격증취득과정(요양보호사', '자격취득과정(비NCS', '요양원', '취득과정(주중', '주말반', '중장년층', '여성가장', '취약계층', '취득(일반', '요양보호사취득-국가자격', '요양보호사1급자격증취득과정', '자격증취득반', '간호조무사자격양성과정', '반', '[일반고특화]간호조무사자격취득및취업과정', '(일반고특화)간호조무사', '(일반고특화)', '간호조무사자격증취득과취업', '차', '클래스', '자격반', '취득과정(주간B', 'NCS요양보호사국가자격증취득과정', '물리치료사', '작업치료사', '양성과정(간호조무사,작업치료사,물리치료사', 'NCS요양보호사자격취득과정', '신규자반', '간호조무사자격증취득반A', '과정A', '간호조무사자격취득과정(주간', '국가전문자격', '간호조무사국가자격', '요양보호사취득과정(사회복지사', '교육과정(간호조무사&물리치료사&작업치료사', '요양병원', '간호조무사자격증취득반B', '요양보호사국가자격취득과정', '요양', '지원', '간병', '서비스', '사회복지사반', '취득과정(신규', '자격취득과정(성남', '한누리', '요양보호사국가자격증취득', '간호조무사자격과정']

# %%
comparelist = ['요양보호사', '간호조무사', '사회복지사', '병원코디네이터', '의료서비스', '국제의료관광코디네이터', '건강보험청구심사']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/06.csv")
# Out:
#                       과정명                           학원명   기간      훈련비  정원  \
# 0     요양보호사 자격 취득과정(비NCS)  세종고운간호전문학원(부설 세종고운요양보호사 교육원)   33   640080  30
# 1        간호조무사자격취득과정(주간C)                        덕천간호학원  191  2903200  30
# 2           요양보호사 자격 취득과정                    한성요양보호사교육원   30   480000  35
# 3            요양보호사자격증취득과정              성모간호학원부설요양보호사교육원   33   600000  34
# 4          요양보호사 자격증 취득과정                    현대요양보호사교육원   35   600000  30
# ...                   ...                           ...  ...      ...  ..
# 2991       간호조무사 자격증 취득과정                   강남메트로간호종합학원  197  3344000  33
# 2992         요양보호사자격증취득과정                    삼성요양보호사교육원   37   640800  30
# 2993          요양보호사자격취득과정                    범계요양보호사교육원   30   588000  40
# 2994       요양보호사 자격증 취득과정                  진해보금요양보호사교육원   32   600000  40
# 2995         병원코디네이터 실무과정              정연화의료서비스아카데미전문학원   20   665160  30
#
#        취업률   연령대 지역1   지역2      NCS       과정
# 0     64.7  55.0  세종   NaN  06_보건의료    요양보호사
# 1     74.7  29.0  부산    북구  06_보건의료    간호조무사
# 2     60.0  56.0  서울   성북구  06_보건의료    요양보호사
# 3     64.1  53.0  전북   정읍시  06_보건의료    요양보호사
# 4     54.3  54.0  울산    남구  06_보건의료    요양보호사
# ...    ...   ...  ..   ...      ...      ...
# 2991  72.5   NaN  서울   강남구  06_보건의료    간호조무사
# 2992  57.3   NaN  경남   통영시  06_보건의료    요양보호사
# 2993  50.5   NaN  경기   안양시  06_보건의료    요양보호사
# 2994  45.7   NaN  경남   창원시  06_보건의료    요양보호사
# 2995  63.6  26.0  부산  부산진구  06_보건의료  병원코디네이터
#
# [2996 rows x 11 columns]
# 과정명      0
# 학원명      0
# 기간       0
# 훈련비      0
# 정원       0
# 취업률      0
# 연령대    185
# 지역1     10
# 지역2     19
# NCS      0
# 과정       0
# dtype: int64
