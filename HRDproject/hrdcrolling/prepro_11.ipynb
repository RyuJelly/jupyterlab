# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %%
df = pd.read_csv("11_경비 청소.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['NCS'] = "11_경비청소"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['청소마스터종합과정', '2차', '대비반', '원샷원킬', '일반경비지도사', '1', '선택', '경호학', '의류수', '과정', '양성과정', '경비지도사', '청소전문가기본과정', '자격증', '취', '창업', '취득', '청소전문', '마스터', '의류제작', '실용의복제작', '수선&리폼', '자격취득', '집중대비반', '세탁기능사', '의복제작', '의류수선실무과정', '청소전문가양성과정(이론+실무', '청소마스터종합', '옷수선&리폼', '세탁기능사자격증', '세탁초급실무', '청소전문가(CLEAN)', '수선', '청소전문가양성과정', '세탁기능사자격증과정']

# %%
comparelist = ['청소마스터', '청소전문', '경비', '세탁', '수선']
fixlist = ['청소전문가', '청소전문가', '경비지도사', '세탁기능사', '의류수선']

courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = fixlist[n]
            break;
        else :
            course = None
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])

df.to_csv("preprocessing/11.csv")
# Out:
#                                과정명         학원명   기간      훈련비   정원   취업률   연령대  \
# 0                        청소마스터종합과정  한국청소직업전문학원   24  1233860   23  50.8  40.0
# 1                        청소마스터종합과정  한국청소직업전문학원   24  1233860   23  50.8  42.0
# 2   원샷원킬! 일반경비지도사 1,2차 대비반(선택-경호학)     한국이러닝협회   56   345800  500  48.3  43.0
# 3                     청소전문가 마스터 과정    내일직업전문학원   25   649400   12  54.5  52.0
# 4                        청소전문가기본과정    내일직업전문학원   20   519520   12  54.5  55.0
# ..                             ...         ...  ...      ...  ...   ...   ...
# 56                         청소마스터종합  한국청소직업전문학원   24  1233860   23  50.8  50.0
# 57                    세탁기능사 자격증 과정    문정세탁기술학원  120  3067200   20  92.3  59.0
# 58                    수선&리폼 및 의류제작    한국일반문화센터   32  1226880   10  34.6  45.0
# 59                       청소전문가양성과정    내일직업전문학원   35   902660   12  54.5  52.0
# 60                   NCS세탁기능사자격증과정    문정세탁기술학원  120  3067200   20  92.3  59.0
#
#    지역1   지역2      NCS     과정
# 0   서울  동대문구  11_경비청소  청소전문가
# 1   서울  동대문구  11_경비청소  청소전문가
# 2   서울   구로구  11_경비청소  경비지도사
# 3   대전    서구  11_경비청소  청소전문가
# 4   대전    서구  11_경비청소  청소전문가
# ..  ..   ...      ...    ...
# 56  서울  동대문구  11_경비청소  청소전문가
# 57  대구   달서구  11_경비청소  세탁기능사
# 58  경기   평택시  11_경비청소   의류수선
# 59  대전    서구  11_경비청소  청소전문가
# 60  대구   달서구  11_경비청소  세탁기능사
#
# [61 rows x 11 columns]
# 과정명    0
# 학원명    0
# 기간     0
# 훈련비    0
# 정원     0
# 취업률    0
# 연령대    0
# 지역1    0
# 지역2    0
# NCS    0
# 과정     0
# dtype: int64
