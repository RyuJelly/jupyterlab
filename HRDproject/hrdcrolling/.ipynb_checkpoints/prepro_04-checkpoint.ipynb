# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %%
df = pd.read_csv("04_교육 자연 사회과학.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['NCS'] = "04_교육자연사회과학"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['한국어교원', '3급', '토픽', '자격취득', '양성과정(이론+문풀', '양성과정', '이론강의', '한국어교원양성과정(3급)', '이론편', '한국어교원양성', '양성(한국어교원', '자격증', '대비반', '문제풀이']

# %%
comparelist = ['한국어교원']
nonelist = []
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = comparelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/04.csv")
# Out:
#                                과정명      학원명   기간     훈련비   정원   취업률   연령대  \
# 0   [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  391500  500  26.0  53.0
# 1    [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  286200  500  26.0   NaN
# 2              한국어교원양성과정(3급) -이론편-  한국이러닝협회   56  383800  500  26.0  51.0
# 3   [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회   56  430650  500  26.0  46.0
# 4    [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회   56  314820  500  26.0   NaN
# ..                             ...      ...  ...     ...  ...   ...   ...
# 59  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500  26.0   NaN
# 60  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500  26.0   NaN
# 61   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500  26.0   NaN
# 62   [토픽] 한국어교원 3급 자격취득 양성과정(이론강의)  한국이러닝협회  105  314820  500  26.0   NaN
# 63  [토픽] 한국어교원 3급 자격취득 양성과정(이론+문풀)  한국이러닝협회  144  430650  500  26.0   NaN
#
#             NCS     과정
# 0   04_교육자연사회과학  한국어교원
# 1   04_교육자연사회과학  한국어교원
# 2   04_교육자연사회과학  한국어교원
# 3   04_교육자연사회과학  한국어교원
# 4   04_교육자연사회과학  한국어교원
# ..          ...    ...
# 59  04_교육자연사회과학  한국어교원
# 60  04_교육자연사회과학  한국어교원
# 61  04_교육자연사회과학  한국어교원
# 62  04_교육자연사회과학  한국어교원
# 63  04_교육자연사회과학  한국어교원
#
# [64 rows x 9 columns]
# 과정명     0
# 학원명     0
# 기간      0
# 훈련비     0
# 정원      0
# 취업률     0
# 연령대    13
# NCS     0
# 과정      0
# dtype: int64
