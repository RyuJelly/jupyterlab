# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re

# %%
df = pd.read_csv("03_금융보험.csv")
df.dropna(subset=['취업률'], inplace=True)
df.reset_index(drop=True, inplace=True)
df.drop('Unnamed: 0', axis=1, inplace=True)
df['NCS'] = "03_금융보험"

df_c = df['과정명'].copy()
df_a = df_c.tolist()
df_a = '\n'.join(df_a)

hannanum = Hannanum()

t = Okt()
tokens_ko = hannanum.nouns(df_a)


ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

sortlist = []
for i in range(len(sortedDict)) :
    sortlist.append(sortedDict[i][0])
print(sortlist)
# Out:
# ['합격', '은행FP(자산관리사)', '비즈니스반', '보험사무원', '총무', '양성과정', '보험총무사무원양성', '보험총무사무원']

# %%
comparelist = ['자산관리사', '보험사무원', '보험총무사무원']
nonelist = ['자산관리사', '보험사무원', '보험사무원']
courselist = []
for i in range(len(df)) :
    for n in range(len(comparelist)) :
        if comparelist[n] in df_c[i] :
            course = nonelist[n]
            break;
        else :
            course = None
            
    courselist.append(course)

df['과정'] = courselist
display(df)

print(df.isnull().sum())
df_p = df['과정'].tolist()
for i in range(len(df_p)) :
    if not(df_p[i]) :
        print(i, df.iloc[i]['과정명'])
        
df.to_csv("preprocessing/03.csv")
# Out:
#                          과정명         학원명  기간      훈련비   정원   취업률   연령대  \
# 0            보험사무원(GA총무)양성과정  인컴트랜드평생교육원  42  1161380   20  93.8  36.0
# 1                    보험총무사무원  부천여성인력개발센터  40  1106080   20  64.3  34.0
# 2            보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8  31.0
# 3                  보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3  36.0
# 4            보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8  35.0
# 5            보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8  34.0
# 6   합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1   NaN
# 7   합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  45.0
# 8   합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  36.0
# 9   합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  35.0
# 10           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8  33.0
# 11                 보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3  39.0
# 12  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  33.0
# 13  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  33.0
# 14  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  29.0
# 15           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8  37.0
# 16  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  33.0
# 17           보험사무원(GA총무)양성과정  인컴트랜드평생교육원  28  1161380   20  93.8   NaN
# 18  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1  42.0
# 19  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1   NaN
# 20  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1   NaN
# 21  합격이 빠른 은행FP(자산관리사) 비즈니스반     한국이러닝협회  83   249480  500  56.1   NaN
# 22                 보험총무사무원양성  은평여성인력개발센터  40  1106080   18  54.3   NaN
#
#         NCS     과정
# 0   03_금융보험  보험사무원
# 1   03_금융보험  보험사무원
# 2   03_금융보험  보험사무원
# 3   03_금융보험  보험사무원
# 4   03_금융보험  보험사무원
# 5   03_금융보험  보험사무원
# 6   03_금융보험  자산관리사
# 7   03_금융보험  자산관리사
# 8   03_금융보험  자산관리사
# 9   03_금융보험  자산관리사
# 10  03_금융보험  보험사무원
# 11  03_금융보험  보험사무원
# 12  03_금융보험  자산관리사
# 13  03_금융보험  자산관리사
# 14  03_금융보험  자산관리사
# 15  03_금융보험  보험사무원
# 16  03_금융보험  자산관리사
# 17  03_금융보험  보험사무원
# 18  03_금융보험  자산관리사
# 19  03_금융보험  자산관리사
# 20  03_금융보험  자산관리사
# 21  03_금융보험  자산관리사
# 22  03_금융보험  보험사무원
# 과정명    0
# 학원명    0
# 기간     0
# 훈련비    0
# 정원     0
# 취업률    0
# 연령대    6
# NCS    0
# 과정     0
# dtype: int64
