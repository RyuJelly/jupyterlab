# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('hrdcrolling/preprocessing/final.csv', index_col = 0)
# df.drop('Unnamed: 0', axis=1, inplace=True)

from matplotlib import font_manager, rc
font_path = "../data/THEdog.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
# Out:
#                                  과정명          학원명   기간      훈련비   정원   취업률  \
# 0                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   42  1161380   20  93.8
# 1                            보험총무사무원   부천여성인력개발센터   40  1106080   20  64.3
# 2                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# 3                          보험총무사무원양성   은평여성인력개발센터   40  1106080   18  54.3
# 4                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# ...                              ...          ...  ...      ...  ...   ...
# 15985                      애견미용사심화과정   동물농장애견미용학원   20   802440   12  50.0
# 15986                [탑강] 유기농업기능사 필기      한국이러닝협회   28   152770  500  20.0
# 15987               [탑강] 유기농업산업기사 필기      한국이러닝협회   49   186500  500  20.0
# 15988                     애견미용사 취업과정  프로펫애완동물관리학원  113  2697530   15  46.9
# 15989  (이론+실기)애견미용반려견스타일리스트3급자격증취득과정   동물농장애견미용학원   80  2009760   15  50.0
#
#         연령대 지역1  지역2      NCS        과정
# 0      36.0  인천  부평구  03_금융보험     보험사무원
# 1      34.0  경기  부천시  03_금융보험     보험사무원
# 2      31.0  인천  부평구  03_금융보험     보험사무원
# 3      36.0  서울  은평구  03_금융보험     보험사무원
# 4      35.0  인천  부평구  03_금융보험     보험사무원
# ...     ...  ..  ...      ...       ...
# 15985   NaN  부산  동래구  24_농림어업     애견미용사
# 15986   NaN  서울  구로구  24_농림어업   유기농업기능사
# 15987   NaN  서울  구로구  24_농림어업  유기농업산업기사
# 15988   NaN  강원  원주시  24_농림어업     애견미용사
# 15989   NaN  부산  동래구  24_농림어업     애견미용사
#
# [15990 rows x 11 columns]

# %%
df1 = df.groupby('과정').count()
c_list = df1.index.tolist()
n_list = df1.과정명.tolist()
count_list = []

for i in range(len(df)):
    for n in range(len(c_list)):
        if df.loc[i]['과정'] in c_list[n]:
            count = n_list[n]
            break;
    count_list.append(count);
    
df['과정수'] = count_list

display(df)
# Out:
#                                  과정명          학원명   기간      훈련비   정원   취업률  \
# 0                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   42  1161380   20  93.8
# 1                            보험총무사무원   부천여성인력개발센터   40  1106080   20  64.3
# 2                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# 3                          보험총무사무원양성   은평여성인력개발센터   40  1106080   18  54.3
# 4                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# ...                              ...          ...  ...      ...  ...   ...
# 15985                      애견미용사심화과정   동물농장애견미용학원   20   802440   12  50.0
# 15986                [탑강] 유기농업기능사 필기      한국이러닝협회   28   152770  500  20.0
# 15987               [탑강] 유기농업산업기사 필기      한국이러닝협회   49   186500  500  20.0
# 15988                     애견미용사 취업과정  프로펫애완동물관리학원  113  2697530   15  46.9
# 15989  (이론+실기)애견미용반려견스타일리스트3급자격증취득과정   동물농장애견미용학원   80  2009760   15  50.0
#
#         연령대 지역1  지역2      NCS        과정  과정수
# 0      36.0  인천  부평구  03_금융보험     보험사무원   11
# 1      34.0  경기  부천시  03_금융보험     보험사무원   11
# 2      31.0  인천  부평구  03_금융보험     보험사무원   11
# 3      36.0  서울  은평구  03_금융보험     보험사무원   11
# 4      35.0  인천  부평구  03_금융보험     보험사무원   11
# ...     ...  ..  ...      ...       ...  ...
# 15985   NaN  부산  동래구  24_농림어업     애견미용사   67
# 15986   NaN  서울  구로구  24_농림어업   유기농업기능사   26
# 15987   NaN  서울  구로구  24_농림어업  유기농업산업기사   26
# 15988   NaN  강원  원주시  24_농림어업     애견미용사   67
# 15989   NaN  부산  동래구  24_농림어업     애견미용사   67
#
# [15990 rows x 12 columns]

# %%
print(df.info())
print(df.describe())

df['일일훈련비'] = df['훈련비'] / df['기간']
ndf = df[['취업률', '과정수', '일일훈련비', '기간', '연령대']]

fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='일일훈련비', y='취업률', data=ndf, ax=ax1)
sns.regplot(x='과정수', y='취업률', data=ndf, ax=ax2, fit_reg=False)

plt.show()
plt.close()

grid_ndf = sns.pairplot(ndf)
plt.savefig('일일훈련비,과정수,기간,연령대,취업률.png')
plt.show()
plt.close()

X = ndf[['기간']]
Y = ndf[['취업률']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=10)
print(len(X_train))
print(len(X_test))

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)

r_square = lr.score(X_test, Y_test)
print(r_square)

# %%
a = df['연령대'] >= 20
tdf = df[a]
b = tdf['연령대'] < 30
tdf = tdf[b]

t = tdf['NCS'] == '19_전기전자'
tdf = tdf[t]
tdf = tdf[['취업률', '과정수', '훈련비', '기간', '연령대']]
display(tdf)

grid_tdf = sns.pairplot(tdf)
plt.savefig('output/20대19_전기전자.png')
plt.show()
plt.close()

X = tdf[['기간']]
Y = tdf[['취업률']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=10)
print(len(X_train))
print(len(X_test))

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)

r_square = lr.score(X_test, Y_test)
print(r_square)

print('기울기', lr.coef_)
print('y절편', lr.intercept_)

Y_hat = lr.predict(X)

plt.figure(figsize=(10,5))
ax1 = sns.distplot(Y, hist=False, label="y")
ax2 = sns.distplot(Y_hat, hist=False, label="y_hat", ax=ax1)
plt.show()
plt.close()
# Out:
#         취업률  과정수      훈련비   기간   연령대
# 11878  87.3   27  9165800  185  28.0
# 11884  52.9  195   467700   56  24.0
# 11887  52.9  195   419800   56  24.0
# 11893  52.9  195   376500   56  25.0
# 11896  52.9  195   550800   56  23.0
# ...     ...  ...      ...  ...   ...
# 12897  64.7   37  9165800  177  23.0
# 12908  55.7  370   785640   40  25.0
# 12912  49.0  446   982050   26  29.0
# 12958  75.0  446   628510   24  27.0
# 12959  45.0  370  1309400   50  24.0
#
# [197 rows x 5 columns]
# 137
# 60
# 0.36956786758515214
# 기울기 [[0.14867567]]
# y절편 [45.61125088]
# C:\Users\wima9\anaconda3\envs\pydatavenv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
# C:\Users\wima9\anaconda3\envs\pydatavenv\lib\site-packages\seaborn\distributions.py:2551: FutureWarning: `distplot` is a deprecated function and will be removed in a future version. Please adapt your code to use either `displot` (a figure-level function with similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#   warnings.warn(msg, FutureWarning)
