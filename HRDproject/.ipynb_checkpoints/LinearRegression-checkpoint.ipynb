# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv('hrdcrolling/preprocessing/final.csv', index_col = 0)
# df.drop('Unnamed: 0', axis=1, inplace=True)
display(df)

from matplotlib import font_manager, rc
font_path = "../data/THEdog.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)
# Out:
#                                  과정명          학원명   기간      훈련비   정원   취업률  \
# 0                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   42  1161380   20  93.8
# 1                            보험총무사무원   부천여성인력개발센터   40  1106080   20  64.3
# 2                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# 3                          보험총무사무원양성   은평여성인력개발센터   40  1106080   18  54.3
# 4                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# ...                              ...          ...  ...      ...  ...   ...
# 15985                      애견미용사심화과정   동물농장애견미용학원   20   802440   12  50.0
# 15986                [탑강] 유기농업기능사 필기      한국이러닝협회   28   152770  500  20.0
# 15987               [탑강] 유기농업산업기사 필기      한국이러닝협회   49   186500  500  20.0
# 15988                     애견미용사 취업과정  프로펫애완동물관리학원  113  2697530   15  46.9
# 15989  (이론+실기)애견미용반려견스타일리스트3급자격증취득과정   동물농장애견미용학원   80  2009760   15  50.0
#
#         연령대 지역1  지역2      NCS        과정
# 0      36.0  인천  부평구  03_금융보험     보험사무원
# 1      34.0  경기  부천시  03_금융보험     보험사무원
# 2      31.0  인천  부평구  03_금융보험     보험사무원
# 3      36.0  서울  은평구  03_금융보험     보험사무원
# 4      35.0  인천  부평구  03_금융보험     보험사무원
# ...     ...  ..  ...      ...       ...
# 15985   NaN  부산  동래구  24_농림어업     애견미용사
# 15986   NaN  서울  구로구  24_농림어업   유기농업기능사
# 15987   NaN  서울  구로구  24_농림어업  유기농업산업기사
# 15988   NaN  강원  원주시  24_농림어업     애견미용사
# 15989   NaN  부산  동래구  24_농림어업     애견미용사
#
# [15990 rows x 11 columns]

# %%
df1 = df.groupby('과정').count()
c_list = df1.index.tolist()
n_list = df1.과정명.tolist()
count_list = []

for i in range(len(df)):
    for n in range(len(c_list)):
        if df.loc[i]['과정'] in c_list[n]:
            count = n_list[n]
            break;
    count_list.append(count);
    
df['과정수'] = count_list

display(df)
# Out:
#                                  과정명          학원명   기간      훈련비   정원   취업률  \
# 0                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   42  1161380   20  93.8
# 1                            보험총무사무원   부천여성인력개발센터   40  1106080   20  64.3
# 2                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# 3                          보험총무사무원양성   은평여성인력개발센터   40  1106080   18  54.3
# 4                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# ...                              ...          ...  ...      ...  ...   ...
# 15985                      애견미용사심화과정   동물농장애견미용학원   20   802440   12  50.0
# 15986                [탑강] 유기농업기능사 필기      한국이러닝협회   28   152770  500  20.0
# 15987               [탑강] 유기농업산업기사 필기      한국이러닝협회   49   186500  500  20.0
# 15988                     애견미용사 취업과정  프로펫애완동물관리학원  113  2697530   15  46.9
# 15989  (이론+실기)애견미용반려견스타일리스트3급자격증취득과정   동물농장애견미용학원   80  2009760   15  50.0
#
#         연령대 지역1  지역2      NCS        과정  과정수
# 0      36.0  인천  부평구  03_금융보험     보험사무원   11
# 1      34.0  경기  부천시  03_금융보험     보험사무원   11
# 2      31.0  인천  부평구  03_금융보험     보험사무원   11
# 3      36.0  서울  은평구  03_금융보험     보험사무원   11
# 4      35.0  인천  부평구  03_금융보험     보험사무원   11
# ...     ...  ..  ...      ...       ...  ...
# 15985   NaN  부산  동래구  24_농림어업     애견미용사   67
# 15986   NaN  서울  구로구  24_농림어업   유기농업기능사   26
# 15987   NaN  서울  구로구  24_농림어업  유기농업산업기사   26
# 15988   NaN  강원  원주시  24_농림어업     애견미용사   67
# 15989   NaN  부산  동래구  24_농림어업     애견미용사   67
#
# [15990 rows x 12 columns]

# %%
print(df.info())
print(df.describe())

df['일일훈련비'] = df['훈련비'] / df['기간']
ndf = df[['취업률', '과정수', '일일훈련비', '기간', '연령대']]

fig = plt.figure(figsize=(10,5))
ax1 = fig.add_subplot(1,2,1)
ax2 = fig.add_subplot(1,2,2)

sns.regplot(x='일일훈련비', y='취업률', data=ndf, ax=ax1)
sns.regplot(x='과정수', y='취업률', data=ndf, ax=ax2, fit_reg=False)

plt.show()
plt.close()

grid_ndf = sns.pairplot(ndf)
plt.savefig('일일훈련비,과정수,기간,연령대,취업률.png')
plt.show()
plt.close()

X = ndf[['기간']]
Y = ndf[['취업률']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=10)
print(len(X_train))
print(len(X_test))

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)

r_square = lr.score(X_test, Y_test)
print(r_square)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 15990 entries, 0 to 15989
# Data columns (total 13 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   과정명     15990 non-null  object
#  1   학원명     15990 non-null  object
#  2   기간      15990 non-null  int64
#  3   훈련비     15990 non-null  int64
#  4   정원      15990 non-null  int64
#  5   취업률     15990 non-null  float64
#  6   연령대     14401 non-null  float64
#  7   지역1     15896 non-null  object
#  8   지역2     15883 non-null  object
#  9   NCS     15990 non-null  object
#  10  과정      15990 non-null  object
#  11  과정수     15990 non-null  int64
#  12  일일훈련비   15990 non-null  float64
# dtypes: float64(3), int64(4), object(6)
# memory usage: 2.3+ MB
# None
#                  기간           훈련비            정원           취업률           연령대  \
# count  15990.000000  1.599000e+04  15990.000000  15990.000000  14401.000000
# mean      62.250156  1.972930e+06     59.146467     55.736354     37.685091
# std       50.575467  2.019332e+06    128.413420     15.569742     10.446434
# min       10.000000  5.670000e+04      5.000000      4.300000     17.000000
# 25%       30.000000  6.285100e+05     15.000000     45.700000     29.000000
# 50%       40.000000  1.075200e+06     20.000000     54.400000     36.000000
# 75%       86.000000  2.869560e+06     30.000000     66.000000     45.000000
# max      392.000000  1.623680e+07    500.000000    100.000000     72.000000
#
#                 과정수          일일훈련비
# count  15990.000000   15990.000000
# mean     685.102814   30258.650808
# std      691.144813   14810.286078
# min        1.000000    2025.000000
# 25%      159.000000   20000.000000
# 50%      430.000000   27188.000000
# 75%     1020.000000   41852.405786
# max     2216.000000  137600.000000
# 11193
# 4797
# 0.24247281100867124

# %%
a = df['연령대'] >= 20
tdf = df[a]
b = tdf['연령대'] < 30
tdf = tdf[b]

t = tdf['과정'] == '응용SW개발자'
tdf = tdf[t]
tdf = tdf[['취업률', '과정수', '훈련비', '기간', '연령대']]
display(tdf)

grid_tdf = sns.pairplot(tdf)
plt.savefig('output/응용SW개발자.png')
plt.show()
plt.close()

X = tdf[['과정수']]
Y = tdf[['취업률']]

from sklearn.model_selection import train_test_split
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size=0.3, random_state=10)
print(len(X_train))
print(len(X_test))

from sklearn.linear_model import LinearRegression

lr = LinearRegression()
lr.fit(X_train, Y_train)

r_square = lr.score(X_test, Y_test)
print(r_square)
# Out:
#         취업률  과정수      훈련비   기간   연령대
# 13099  83.6  189  4743360  120  24.0
# 13112  77.8  189  6588000  125  25.0
# 13117  84.4  189  6588000  125  26.0
# 13118  95.5  189  6324480  120  27.0
# 13124  65.4  189  5797440  110  24.0
# ...     ...  ...      ...  ...   ...
# 14048  75.2  189  6389200  120  25.0
# 14053  83.3  189  5929200  113  27.0
# 14064  81.0  189  5929200  113  25.0
# 14128  66.7  189  4888290  119  27.0
# 14191  84.4  189  5929200  113  26.0
#
# [149 rows x 5 columns]
# 104
# 45
# -0.000135968416686838
