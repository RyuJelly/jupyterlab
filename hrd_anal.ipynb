# %%
import pandas as pd
import numpy as np

df = pd.read_csv("전처리/final.csv", index_col = 0)

display(df)
# Out:
#                                  과정명          학원명   기간      훈련비   정원   취업률  \
# 0                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   42  1161380   20  93.8
# 1                            보험총무사무원   부천여성인력개발센터   40  1106080   20  64.3
# 2                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# 3                          보험총무사무원양성   은평여성인력개발센터   40  1106080   18  54.3
# 4                    보험사무원(GA총무)양성과정   인컴트랜드평생교육원   28  1161380   20  93.8
# ...                              ...          ...  ...      ...  ...   ...
# 15985                      애견미용사심화과정   동물농장애견미용학원   20   802440   12  50.0
# 15986                [탑강] 유기농업기능사 필기      한국이러닝협회   28   152770  500  20.0
# 15987               [탑강] 유기농업산업기사 필기      한국이러닝협회   49   186500  500  20.0
# 15988                     애견미용사 취업과정  프로펫애완동물관리학원  113  2697530   15  46.9
# 15989  (이론+실기)애견미용반려견스타일리스트3급자격증취득과정   동물농장애견미용학원   80  2009760   15  50.0
#
#         연령대 지역1  지역2      NCS        과정
# 0      36.0  인천  부평구  03_금융보험     보험사무원
# 1      34.0  경기  부천시  03_금융보험     보험사무원
# 2      31.0  인천  부평구  03_금융보험     보험사무원
# 3      36.0  서울  은평구  03_금융보험     보험사무원
# 4      35.0  인천  부평구  03_금융보험     보험사무원
# ...     ...  ..  ...      ...       ...
# 15985   NaN  부산  동래구  24_농림어업     애견미용사
# 15986   NaN  서울  구로구  24_농림어업   유기농업기능사
# 15987   NaN  서울  구로구  24_농림어업  유기농업산업기사
# 15988   NaN  강원  원주시  24_농림어업     애견미용사
# 15989   NaN  부산  동래구  24_농림어업     애견미용사
#
# [15990 rows x 11 columns]

# %% [markdown]
# ## 폰트설정

# %%
from matplotlib import font_manager, rc
font_path = "data/THEdog.ttf"   #폰트파일의 위치
font_name = font_manager.FontProperties(fname=font_path).get_name()
rc('font', family=font_name)

# %% [markdown]
# ## 0. 분야별 수업 수

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 구역 설정
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(1, 1, 1)

# 그래프 그리기
sns.countplot(x="NCS",data=df, palette="rocket", order = df['NCS'].value_counts().index, ax=ax1)
plt.xticks(size=14, rotation=70)
plt.yticks(size=14)
plt.grid(True)

# 텍스트 설정

# 출력 
plt.show()

# %% [markdown]
# ## 1. 과정별 취업률 통계

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 전처리
df_Bycourse = df.loc[:,['NCS','취업률']]
grouped = df_Bycourse.groupby(['NCS'])
df_Bycourse = grouped.mean()
df_Bycourse.sort_values(by=['취업률'], ascending=False, inplace=True)

# 구역 설정
fig = plt.figure(figsize=(20, 10))
ax1 = fig.add_subplot(1, 1, 1)

# 그래프 그리기
sns.barplot(x=df_Bycourse.index, y="취업률", data=df_Bycourse, palette="rocket", ax=ax1)
plt.xticks(size=14, rotation=70)
plt.yticks(size=14)
plt.grid(True)
plt.ylim(20, 75)

# 텍스트 설정

# 출력 
plt.show()

# %% [markdown]
# ## 2. 학원기준 과정의 개수(전문성) & 취업률

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# 전처리
df_academy_course = df.loc[:,['학원명','과정']]

a = df_academy_course.drop_duplicates(subset = ['학원명','과정'])
grouped = a.groupby(['학원명'])
df_academy_course = grouped.count()
display(df_academy_course)

df_academy_rate = df.loc[:,['학원명','취업률']]
grouped = df_academy_rate.groupby(['학원명'])
df_academy_rate = grouped.mean()
display(df_academy_rate)

final = pd.merge(df_academy_course, df_academy_rate, on='학원명')
display(final)

fig = plt.figure(figsize=(20, 10))   
ax1 = fig.add_subplot(1, 1, 1)
sns.boxplot(x='과정', y='취업률', data=final, ax=ax1)
plt.show()
plt.close()
# Out:
#                                    과정
# 학원명
# (사)한국디지털컨버전스협회                      5
# (사)한국여학사협회 강북여성인력개발센터 부설 요양보호사교육원   1
# (사단법인)한국플랜트산업협회                     1
# (재)BBS미용예술실용전문학교                    3
# (재)건설기술교육원                          5
# ...                                ..
# 휴앤아이간호학원                            1
# 휴앤아이간호학원(용인수지점)                     1
# 휴평생직업교육학원                           1
# 희망요양보호사교육원                          1
# 희망직업전문학교                            1
#
# [1454 rows x 1 columns]
#                                          취업률
# 학원명
# (사)한국디지털컨버전스협회                     33.397794
# (사)한국여학사협회 강북여성인력개발센터 부설 요양보호사교육원  40.000000
# (사단법인)한국플랜트산업협회                    49.500000
# (재)BBS미용예술실용전문학교                   66.900000
# (재)건설기술교육원                         51.172222
# ...                                      ...
# 휴앤아이간호학원                           75.800000
# 휴앤아이간호학원(용인수지점)                    79.600000
# 휴평생직업교육학원                          91.700000
# 희망요양보호사교육원                         48.000000
# 희망직업전문학교                           58.800000
#
# [1454 rows x 1 columns]
#                                    과정        취업률
# 학원명
# (사)한국디지털컨버전스협회                      5  33.397794
# (사)한국여학사협회 강북여성인력개발센터 부설 요양보호사교육원   1  40.000000
# (사단법인)한국플랜트산업협회                     1  49.500000
# (재)BBS미용예술실용전문학교                    3  66.900000
# (재)건설기술교육원                          5  51.172222
# ...                                ..        ...
# 휴앤아이간호학원                            1  75.800000
# 휴앤아이간호학원(용인수지점)                     1  79.600000
# 휴평생직업교육학원                           1  91.700000
# 희망요양보호사교육원                          1  48.000000
# 희망직업전문학교                            1  58.800000
#
# [1454 rows x 2 columns]

# %% [markdown]
# ## 3. 분야별 취업률이 높은 학원

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("HRDproject/hrdcrolling/preprocessing/final.csv", index_col = 0)

df_academy_rank = df.loc[:,['NCS','학원명','취업률','지역1']]
df_academy_rank = df_academy_rank.groupby(['NCS','학원명','지역1']).mean()
display(df_academy_rank)

df_academy_03 = df_academy_rank.loc['24_농림어업'].sort_values(by=['취업률'], ascending=False)
display(df_academy_03)
df_academy_03.reset_index(level=['지역1'], inplace = True)
display(df_academy_03)

fig = plt.figure(figsize=(20, 10))   
ax1 = fig.add_subplot(1, 1, 1)
sns.barplot(x=df_academy_03.index, y='취업률', hue='지역1', data=df_academy_03, ax=ax1)
plt.show()
plt.close()
# Out:
#                               취업률
# NCS         학원명         지역1
# 03_금융보험     부천여성인력개발센터  경기   64.3
#             은평여성인력개발센터  서울   54.3
#             인컴트랜드평생교육원  인천   93.8
#             한국이러닝협회     서울   56.1
# 04_교육자연사회과학 은평여성인력개발센터  서울   21.7
# ...                           ...
# 24_농림어업     중앙애견미용학원    경기    4.3
#                         서울   61.1
#             킴스애견미용학원    서울   47.6
#             프로펫애완동물관리학원 강원   46.9
#             한국이러닝협회     서울   20.0
#
# [1912 rows x 1 columns]
#                   취업률
# 학원명         지역1
# 중앙애견미용학원    서울   61.1
# 숲생태조경인재개발학원 인천   57.9
# 에이스애견미용학원   경기   51.5
# 동물농장애견미용학원  부산   50.0
# HS평생교육원     인천   48.0
# 킴스애견미용학원    서울   47.6
# 프로펫애완동물관리학원 강원   46.9
# 웰빙펫애견미용학원   부산   39.6
# 이정민애견미용학원   대전   33.3
# 서울애완동물관리학원  서울   26.8
# 제이제이애견미용학원  서울   25.5
# 이상훈애견미용학원   대구   23.3
# 한국이러닝협회     서울   20.0
# 중앙애견미용학원    경기    4.3
#             지역1   취업률
# 학원명
# 중앙애견미용학원     서울  61.1
# 숲생태조경인재개발학원  인천  57.9
# 에이스애견미용학원    경기  51.5
# 동물농장애견미용학원   부산  50.0
# HS평생교육원      인천  48.0
# 킴스애견미용학원     서울  47.6
# 프로펫애완동물관리학원  강원  46.9
# 웰빙펫애견미용학원    부산  39.6
# 이정민애견미용학원    대전  33.3
# 서울애완동물관리학원   서울  26.8
# 제이제이애견미용학원   서울  25.5
# 이상훈애견미용학원    대구  23.3
# 한국이러닝협회      서울  20.0
# 중앙애견미용학원     경기   4.3
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50521 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49714 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49373 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53468 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50977 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 53428 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54187 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50756 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50928 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48729 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48124 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54984 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47084 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45789 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54801 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52712 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 52380 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:238: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51473 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50521 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50528 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48120 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50857 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54617 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50896 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49714 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49373 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53468 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51312 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51064 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51116 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48156 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50640 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51060 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49828 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 46041 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47932 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45453 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51109 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54217 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44368 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50977 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 53428 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47196 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54187 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50756 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44288 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47532 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50928 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48729 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51221 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48124 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49436 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50872 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51228 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49345 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54984 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54620 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44397 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47084 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45789 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54801 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 54924 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47749 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52712 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50629 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 47456 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51648 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 50669 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 52380 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44592 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 48512 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 49328 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44053 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 45824 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 51204 missing from current font.
#   font.set_text(s, 0, flags=flags)
# C:\Users\i\.conda\envs\pydatavenv\lib\site-packages\matplotlib\backends\backend_agg.py:201: RuntimeWarning: Glyph 44396 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ## 4. 지역별 취업률 순위

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_csv("전처리/final.csv", index_col = 0)

df_local_rate = df.loc[:,['지역1','과정','취업률']]

df_local_rate = df_local_rate.groupby(['지역1','과정']).mean()
df_local_rate = df_local_rate.loc['서울'].sort_values(by=['취업률'], ascending=False)

display(df_local_rate.loc['빅데이터'])
# Out:
# 취업률    62.816807
# Name: 빅데이터, dtype: float64
