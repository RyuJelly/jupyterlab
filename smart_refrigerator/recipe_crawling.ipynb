# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
driver = webdriver.Chrome('c:/Temp/chromedriver')
driver.implicitly_wait(6) 
driver.get('https://www.10000recipe.com/recipe/list.html?q=&query=&cat1=&cat2=&cat3=70&cat4=&fct=&order=reco&lastcate=cat3&dsearch=&copyshot=&scrap=&degree=&portion=&time=&niresource=')
time.sleep(4)


start = time.time()

recipe_list = []
main_list = []
food_list = []
food = []
ingredient_list = []
ingredient = []
ingredient_name_list = []
ingredient_name = []
seasoning_list = []
seasoning = []
seasoning_name_list =[]
seasoning_name = []

recipe_num = 1;
while True:    
    # 마지막 레시피 체크
    if recipe_num == 5:
        break;
    # 레시피 선택
    select_recipe = driver.find_element_by_css_selector('ul > ul > li:nth-child('+ str(recipe_num) +') > div.common_sp_thumb > a > img')
    if not select_recipe:
        break;
    select_recipe.click()
    time.sleep(2)
    
    # 음식이름
    name_list = driver.find_elements_by_css_selector(' div.view2_summary.st3 > h3')
    for name in name_list:
        food.append(name.text)

    # 재료
    countA = 2;
    while True:
        ing_list = driver.find_elements_by_css_selector('  ul:nth-child(1) > a:nth-child('+ str(countA) +') > li')
        if len(ing_list) == 0 :
            break;
        for name in ing_list:
            ingredient.append(name.text.replace('\n', '_'))
            text = name.text.split('\n')
            ingredient_name.append(text[0])
        countA += 1;

    # 양념
    countB =2; 
    while True:
        ssn_list = driver.find_elements_by_css_selector('  ul:nth-child(2) > a:nth-child('+ str(countB) +') > li')
        if len(ssn_list) == 0 :
            break;
        for name in ssn_list:
            seasoning.append(name.text.replace('\n', '_'))
            text = name.text.split('\n')
            seasoning_name.append(text[0])
        countB += 1;

    food_str = ",".join(food)
    food = []
    food_list.append(food_str)
    
    ingredient_str = ",".join(ingredient)
    ingredient = []
    ingredient_list.append(ingredient_str)
    ingredient_name_str = " ".join(ingredient_name)
    ingredient_name = []
    ingredient_name_list.append(ingredient_name_str)
    
    seasoning_str = ",".join(seasoning)
    seasoning = []
    seasoning_list.append(seasoning_str)
    seasoning_name_str = " ".join(seasoning_name)
    seasoning_name =[]
    seasoning_name_list.append(seasoning_name_str)
    
    recipe_num += 1;
    except_list = [6, 15, 26, 35]
    if recipe_num in except_list :
        recipe_num += 1;
    driver.back()
    driver.get('https://www.10000recipe.com/recipe/list.html?q=&query=&cat1=&cat2=&cat3=70&cat4=&fct=&order=reco&lastcate=cat3&dsearch=&copyshot=&scrap=&degree=&portion=&time=&niresource=')
    time.sleep(4)

df = pd.DataFrame({"food" : food_list,
                   "ingredient" : ingredient_list,
                   "seasoning" : seasoning_list,
                   "ingredint_name" : ingredient_name_list, 
                   "seasoning_name" : seasoning_name_list})

df.to_csv("./output/test2.csv", index=False)
        
driver.quit()
print("time: ", time.time()-start)
# Out:
# time:  87.77487397193909

# %%
driver = webdriver.Chrome('c:/Temp/chromedriver')
driver.implicitly_wait(6) 
driver.get('https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=141')
time.sleep(4)

pnum = 2;
while True:
    next_page = driver.find_element_by_css_selector("#contents_area_full > ul > nav > ul > li:nth-child("+ str(pnum) +") > a")
    ppnum = pnum + 1;
    page_check = driver.find_elements_by_css_selector("#contents_area_full > ul > nav > ul > li:nth-child("+ str(ppnum) +") > a")
    if page_check :
        next_page.click()
        pnum += 1;
    else :
        if pnum == 12 :
            next_page.click()
            pnum = 3;
        else :
            break;

driver.quit()
# Out:
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=141
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=141
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=142
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=143
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=144
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=145
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=146
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=147
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=148
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=149
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=150
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=151
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=152
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=153
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=154
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=155
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=156
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=157

# %%
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
driver = webdriver.Chrome('c:/Temp/chromedriver')
driver.implicitly_wait(6) 
driver.get('https://www.10000recipe.com/recipe/list.html?q=&query=&cat1=&cat2=&cat3=70&cat4=&fct=&order=reco&lastcate=cat3&dsearch=&copyshot=&scrap=&degree=&portion=&time=&niresource=')
time.sleep(4)


start = time.time()

recipe_list = []
main_list = []
food_list = []
food = []
ingredient_list = []
ingredient = []
ingredient_name_list = []
ingredient_name = []
seasoning_list = []
seasoning = []
seasoning_name_list =[]
seasoning_name = []

recipe_num = 1;
pnum = 2;
# 첫 1~10페이지 체크용
page = 1; 

while True:    
    # 마지막 레시피 체크
    if recipe_num == 3:
        # 페이지 이동
        next_page = driver.find_element_by_css_selector("#contents_area_full > ul > nav > ul > li:nth-child("+ str(pnum) +") > a")
        ppnum = pnum + 1;
        page_check = driver.find_elements_by_css_selector("#contents_area_full > ul > nav > ul > li:nth-child("+ str(ppnum) +") > a")
        if page_check :
            next_page.click()
            page += 1;
            time.sleep(4)
            pnum += 1;
            recipe_num = 1;
        else :
            if pnum == 12 :
                next_page.click()
                page += 1;
                time.sleep(4)
                pnum = 3;
                recipe_num = 1;
            else :
                if page > 12:
                    break;

    url = driver.current_url
    print(url)
    # 레시피 선택
    select_recipe = driver.find_element_by_css_selector('ul > ul > li:nth-child('+ str(recipe_num) +') > div.common_sp_thumb > a > img')
    if not select_recipe:
        break;
    select_recipe.click()
    time.sleep(2)
    
    # 음식이름
    name_list = driver.find_elements_by_css_selector(' div.view2_summary.st3 > h3')
    for name in name_list:
        food.append(name.text)

    # 재료
    countA = 2;
    while True:
        ing_list = driver.find_elements_by_css_selector('  ul:nth-child(1) > a:nth-child('+ str(countA) +') > li')
        if len(ing_list) == 0 :
            break;
        for name in ing_list:
            ingredient.append(name.text.replace('\n', '_'))
            text = name.text.split('\n')
            ingredient_name.append(text[0])
        countA += 1;

    # 양념
    countB =2; 
    while True:
        ssn_list = driver.find_elements_by_css_selector('  ul:nth-child(2) > a:nth-child('+ str(countB) +') > li')
        if len(ssn_list) == 0 :
            break;
        for name in ssn_list:
            seasoning.append(name.text.replace('\n', '_'))
            text = name.text.split('\n')
            seasoning_name.append(text[0])
        countB += 1;

    food_str = ",".join(food)
    food = []
    food_list.append(food_str)
    
    ingredient_str = ",".join(ingredient)
    ingredient = []
    ingredient_list.append(ingredient_str)
    ingredient_name_str = " ".join(ingredient_name)
    ingredient_name = []
    ingredient_name_list.append(ingredient_name_str)
    
    seasoning_str = ",".join(seasoning)
    seasoning = []
    seasoning_list.append(seasoning_str)
    seasoning_name_str = " ".join(seasoning_name)
    seasoning_name =[]
    seasoning_name_list.append(seasoning_name_str)
    
    recipe_num += 1;
    except_list = [6, 15, 26, 35]
    if recipe_num in except_list :
        recipe_num += 1;
    driver.back()
    driver.get(url)
    time.sleep(4)

df = pd.DataFrame({"food" : food_list,
                   "ingredient" : ingredient_list,
                   "seasoning" : seasoning_list,
                   "ingredint_name" : ingredient_name_list, 
                   "seasoning_name" : seasoning_name_list})

df.to_csv("./output/test3.csv", index=False)
        
driver.quit()
print("time: ", time.time()-start)
# Out:
# https://www.10000recipe.com/recipe/list.html?q=&query=&cat1=&cat2=&cat3=70&cat4=&fct=&order=reco&lastcate=cat3&dsearch=&copyshot=&scrap=&degree=&portion=&time=&niresource=
# https://www.10000recipe.com/recipe/list.html?q=&query=&cat1=&cat2=&cat3=70&cat4=&fct=&order=reco&lastcate=cat3&dsearch=&copyshot=&scrap=&degree=&portion=&time=&niresource=
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=2
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=2
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=3
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=3
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=4
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=4
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=5
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=5
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=6
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=6
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=7
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=7
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=8
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=8
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=9
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=9
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=10
# https://www.10000recipe.com/recipe/list.html?cat3=70&order=reco&page=10
# time:  487.92379546165466

# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re
df = pd.read_csv('output/test.csv')
sample = df['ingredient'][0]
print(sample)

hannanum = Hannanum()

Okt = Okt()
tokens_ko = hannanum.nouns(sample)
# print(tokens_ko)
ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
a = Okt.nouns(sample)
pprint(a)
a = np.array(a)
b = ['차돌박이', '팽이버섯']
b = np.array(b)
# pprint(Okt.morphs(sample))
# pprint(Okt.pos(sample))
print(a)
print(b)
# Out:
# 차돌박이_10장,깻잎_5장,팽이버섯_1묶음,숙주나물_1주먹
# ['차돌박이', '장', '깻잎', '장', '팽이버섯', '묶음', '숙주나물', '주먹']
# ['차돌박이' '장' '깻잎' '장' '팽이버섯' '묶음' '숙주나물' '주먹']
# ['차돌박이' '팽이버섯']

# %%
from numpy import dot
from numpy.linalg import norm
import numpy as np
def cos_sim(A, B):
       return dot(A, B)/(norm(A)*norm(B))
    
print(cos_sim(a,b))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-fdea7f66145a> in <module>
#       5        return dot(A, B)/(norm(A)*norm(B))
#       6
# ----> 7 print(cos_sim(a,b))
#
# <ipython-input-22-fdea7f66145a> in cos_sim(A, B)
#       3 import numpy as np
#       4 def cos_sim(A, B):
# ----> 5        return dot(A, B)/(norm(A)*norm(B))
#       6
#       7 print(cos_sim(a,b))
#
# <__array_function__ internals> in dot(*args, **kwargs)
#
# ValueError: shapes (8,) and (2,) not aligned: 8 (dim 0) != 2 (dim 0)
