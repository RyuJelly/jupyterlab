# %%
import pandas as pd
from konlpy.tag import Okt
from konlpy.utils import pprint
import nltk
from konlpy.tag import Hannanum 
import re
# df = pd.read_csv("./output/test.csv")
# df['ingredint_name'].fillna('', inplace=True)
# data = df['ingredint_name'].tolist()
# data = '\n'.join(data)
# data = re.sub('[^가-힣]', ' ', str(data))

df2 = pd.read_csv("./output/최종레시피2.csv")
df2['ingredient_name'].fillna('', inplace=True)
data2 = df2['ingredient_name'].tolist()
data2 = '\n'.join(data2)
# data2 = re.sub('[^가-힣]', ' ', str(data2))

hannanum = Hannanum()

# %%
    
t = Okt()
tokens_ko = hannanum.nouns(data2)
print('tokens_ko',tokens_ko)
print('\n')

ko_ = nltk.Text(tokens_ko)  
ko_.vocab()
freq_dic = dict(ko_.vocab())
print('freq_dic',freq_dic)
print('\n')
sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)
sortedDict = sorted(freq_dic.items(), key=lambda x: x[1], reverse=True)

print(sortedDict)

# %%
print(type(df['ingredint_name'][0]))
print(df['ingredint_name'][0])
print(type(df2['ingredient_name'][0]))
print(df2['ingredient_name'][0])
print(type(data))
print(data)
# Out:
# <class 'str'>
# 소고기 불고깃감 새송이버섯 팽이버섯 느타리버섯 만가닥 버섯 말린 표고버섯 양파 쑥갓 당면
# <class 'str'>
# 가지 소시지 계란 양파 쪽파 적채 당근 게맛살 브로콜리
# <class 'str'>
# ...
