# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from pyvirtualdisplay import Display
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []
ingredient_name = []
ingredient_name_list = []
seasoning_name = []
seasoning_name_list = []

recipe_num = 6947317
check_num = 1;

while True:
    req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
    html = req.text
    if len(html) < 100:
        while True:
            recipe_num -= 1;
            req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
            html = req.text
            if len(html) > 200:
                break;
        
    bs = BeautifulSoup(html, 'html.parser')
    
    # 크롤링 확인용
    print(check_num, ':', recipe_num, sep='', end=', ')
    
    # 음식이름
    d_food = bs.select('#contents_area > div.view2_summary.st3 > h3')
    food = [dom.text for dom in d_food]
    food_str = ''.join(food)
    food = []
    food_list.append(food_str)

    # 재료
    d_ingredient = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1)')
    ingredient_str = [dom.text for dom in d_ingredient]
    ingredient_str = ''.join(ingredient_str).split()[1:]
    ingredient_list.append(ingredient_str)
    ingredient_str = []

    
    # 재료명 (유사도검사를 위한)
    inum = 1;
    while True:
        d_ingredient_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1) > a:nth-of-type('+ str(inum) +') > li')
        if not d_ingredient_name :
            break;
        inum += 1;
        ingredient_name_str = [dom.text for dom in d_ingredient_name]
        ingredient_name_str = ''.join(ingredient_name_str).split()[0]
        ingredient_name.append(ingredient_name_str)
        ingredient_name_str = []
    ingredient_name = ' '.join(ingredient_name)
    ingredient_name_list.append(ingredient_name)
    ingredient_name = []
    
    # 양념
    d_seasoning = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2)')
    seasoning_str = [dom.text for dom in d_seasoning]
    seasoning_str = ''.join(seasoning_str).split()[1:]
    seasoning_list.append(seasoning_str)
    seasoning_str = []

    
    # 양념 재료명 (유사도검사를 위한)
    snum = 1;
    while True:
        d_seasoning_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2) > a:nth-of-type('+ str(snum) +') > li')
        if not d_seasoning_name :
            break;
        snum += 1;
        seasoning_name_str = [dom.text for dom in d_seasoning_name]
        seasoning_name_str = ''.join(seasoning_name_str).split()[0]
        seasoning_name.append(seasoning_name_str)
        seasoning_name_str = []
    seasoning_name = ' '.join(seasoning_name)
    seasoning_name_list.append(seasoning_name)
    seasoning_name = []
    

    # 조리방법
    cnum = 1;
    while True:
        d_howto = bs.select('#stepdescr'+ str(cnum))
        hlist = [dom.text for dom in d_howto]
        if not hlist:
            break;        
        hlist = hlist[0]
        howtolist = str(cnum) + '. ' + hlist
        how_to_str.append(howtolist)
        hlist = []
        cnum += 1;
    if not how_to_str:
        d_howto = bs.select('.view_step')
        hlist = [dom.text for dom in d_howto][0].replace('원본보기', '').replace('\n', '')
        how_to_str = hlist.split("\r")[0].split('\xa0')
        how_to_str = [a for a in how_to_str if a]
        hlist = []
    how_to_list.append(how_to_str)
    how_to_str = []
    
    recipe_num_list.append(recipe_num)
    
    recipe_num -= 1;
    check_num += 1;
    if recipe_num == 6937317:
        break;
    

df = pd.DataFrame({"name" : food_list,
                   "ingredient" : ingredient_list,
                   "ingredient_name" : ingredient_name_list,
                   "seasoning" : seasoning_list,
                   "seasoning_name" : seasoning_name_list,
                   "howto" : how_to_list,
                   "recipe_num" : recipe_num_list})  

df.to_csv("./output/최종레시피1.csv", index=False)
        
print("time: ", time.time()-start)
# Out:
# 1:6947317, 2:6947316, 3:6947315, 4:6947314, 5:6947313, 6:6947312, 7:6947311, 8:6947310, 9:6947309, 10:6947308, 11:6947307, 12:6947306, 13:6947305, 14:6947304, 15:6947303, 16:6947302, 17:6947301, 18:6947300, 19:6947299, 20:6947298, 21:6947297, 22:6947296, 23:6947295, 24:6947294, 25:6947293, 26:6947292, 27:6947291, 28:6947290, 29:6947289, 30:6947288, 31:6947286, 32:6947285, 33:6947284, 34:6947283, 35:6947282, 36:6947281, 37:6947280, 38:6947279, 39:6947278, 40:6947277, 41:6947276, 42:6947275, 43:6947274, 44:6947273, 45:6947272, 46:6947270, 47:6947269, 48:6947267, 49:6947266, 50:6947265, 51:6947264, 52:6947263, 53:6947262, 54:6947261, 55:6947260, 56:6947259, 57:6947258, 58:6947257, 59:6947256, 60:6947255, 61:6947254, 62:6947253, 63:6947252, 64:6947251, 65:6947250, 66:6947249, 67:6947248, 68:6947247, 69:6947246, 70:6947244, 71:6947243, 72:6947242, 73:6947241, 74:6947240, 75:6947239, 76:6947238, 77:6947237, 78:6947236, 79:6947235, 80:6947234, 81:6947233, 82:6947232, 83:6947231, 84:6947230, 85:6947229, 86:6947228, 87:6947227, 88:6947226, 89:6947225, 90:6947224, 91:6947223, 92:6947222, 93:6947221, 94:6947220, 95:6947219, 96:6947218, 97:6947217, 98:6947216, 99:6947215, 100:6947214, 101:6947213, 102:6947212, 103:6947211, 104:6947210, 105:6947209, 106:6947208, 107:6947207, 108:6947206, 109:6947205, 110:6947204, 111:6947203, 112:6947202, 113:6947201, 114:6947200, 115:6947199, 116:6947198, 117:6947197, 118:6947196, 119:6947193, 120:6947192, 121:6947191, 122:6947190, 123:6947188, 124:6947187, 125:6947186, 126:6947185, 127:6947184, 128:6947183, 129:6947182, 130:6947181, 131:6947180, 132:6947179, 133:6947178, 134:6947177, 135:6947175, 136:6947174, 137:6947173, 138:6947172, 139:6947171, 140:6947170, 141:6947169, 142:6947168, 143:6947167, 144:6947166, 145:6947165, 146:6947164, 147:6947163, 148:6947162, 149:6947161, 150:6947160, 151:6947159, 152:6947158, 153:6947157, 154:6947156, 155:6947155, 156:6947154, 157:6947153, 158:6947152, 159:6947151, 160:6947150, 161:6947149, 162:6947148, 163:6947147, 164:6947146, 165:6947145, 166:6947144, 167:6947143, 168:6947142, 169:6947141, 170:6947140, 171:6947139, 172:6947138, 173:6947137, 174:6947136, 175:6947135, 176:6947134, 177:6947133, 178:6947132, 179:6947131, 180:6947130, 181:6947129, 182:6947128, 183:6947127, 184:6947126, 185:6947125, 186:6947124, 187:6947123, 188:6947122, 189:6947121, 190:6947120, 191:6947119, 192:6947118, 193:6947117, 194:6947116, 195:6947115, 196:6947114, 197:6947113, 198:6947112, 199:6947111, 200:6947110, 201:6947109, 202:6947108, 203:6947107, 204:6947106, 205:6947105, 206:6947104, 207:6947103, 208:6947102, 209:6947101, 210:6947100, 211:6947099, 212:6947098, 213:6947097, 214:6947096, 215:6947095, 216:6947094, 217:6947093, 218:6947092, 219:6947091, 220:6947090, 221:6947089, 222:6947088, 223:6947087, 224:6947086, 225:6947085, 226:6947084, 227:6947083, 228:6947082, 229:6947081, 230:6947080, 231:6947079, 232:6947078, 233:6947077, 234:6947076, 235:6947075, 236:6947074, 237:6947073, 238:6947072, 239:6947071, 240:6947070, 241:6947069, 242:6947068, 243:6947067, 244:6947066, 245:6947065, 246:6947064, 247:6947063, 248:6947062, 249:6947061, 250:6947060, 251:6947059, 252:6947058, 253:6947057, 254:6947056, 255:6947055, 256:6947054, 257:6947053, 258:6947052, 259:6947051, 260:6947050, 261:6947049, 262:6947048, 263:6947047, 264:6947046, 265:6947045, 266:6947044, 267:6947043, 268:6947042, 269:6947041, 270:6947040, 271:6947039, 272:6947038, 273:6947037, 274:6947036, 275:6947035, 276:6947034, 277:6947033, 278:6947032, 279:6947031, 280:6947030, 281:6947029, 282:6947028, 283:6947027, 284:6947026, 285:6947025, 286:6947024, 287:6947023, 288:6947022, 289:6947021, 290:6947020, 291:6947019, 292:6947018, 293:6947017, 294:6947016, 295:6947015, 296:6947014, 297:6947013, 298:6947012, 299:6947010, 300:6947009, 301:6947008, 302:6947007, 303:6947006, 304:6947005, 305:6947004, 306:6947003, 307:6947002, 308:6947001, 309:6947000, 310:6946999, 311:6946998, 312:6946997, 313:6946996, 314:6946995, 315:6946994, 316:6946993,  ...

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from pyvirtualdisplay import Display
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []

recipe_num = 6947317
check_num = 1;

while True:
    req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
    html = req.text
    if len(html) < 100:
        while True:
            recipe_num -= 1;
            req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
            html = req.text
            if len(html) > 200:
                break;
        
    bs = BeautifulSoup(html, 'html.parser')
    
    print(check_num, ':', recipe_num, sep='', end=', ')
    # 음식이름
    d_food = bs.select('#contents_area > div.view2_summary.st3 > h3')
    food = [dom.text for dom in d_food]
    food_str = ''.join(food)
    food = []
    food_list.append(food_str)

    # 재료
    d_ingredient = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(1)')
    ingredient_str = [dom.text for dom in d_ingredient]
    ingredient_str = ''.join(ingredient_str).split()[1:]
    ingredient_list.append(ingredient_str)
    ingredient_str = []



    # 양념
    d_seasoning = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2)')
    seasoning_str = [dom.text for dom in d_seasoning]
    seasoning_str = ''.join(seasoning_str).split()[1:]
    seasoning_list.append(seasoning_str)
    seasoning_str = []


    # 조리방법
    cnum = 1;
    while True:
        d_howto = bs.select('#stepdescr'+ str(cnum))
        hlist = [dom.text for dom in d_howto]
        if not hlist:
            break;        
        hlist = hlist[0]
        howtolist = str(cnum) + '. ' + hlist
        how_to_str.append(howtolist)
        hlist = []
        cnum += 1;
    if not how_to_str:
        d_howto = bs.select('.view_step')
        hlist = [dom.text for dom in d_howto][0].replace('원본보기', '').replace('\n', '')
        how_to_str = hlist.split("\r")[0].split('\xa0')
        how_to_str = [a for a in how_to_str if a]
        hlist = []
    how_to_list.append(how_to_str)
    how_to_str = []
    
    recipe_num_list.append(recipe_num)
    
    recipe_num -= 1;
    check_num += 1;
    if recipe_num == 6927317:
        break;
    

df = pd.DataFrame({"name" : food_list,
                   "ingredient" : ingredient_list,
                   "seasoning" : seasoning_list,
                   "howto" : how_to_list,
                   "recipe_num" : recipe_num_list})  

df.to_csv("./output/recipe_2.csv", index=False)
        
print("time: ", time.time()-start)

# %%
import requests
from bs4 import BeautifulSoup
import re
import time
import pandas as pd
import numpy as np
from selenium import webdriver
from selenium.webdriver.common.keys import Keys
from selenium.webdriver.chrome.options import Options

# 시작번호 https://www.10000recipe.com/recipe/6947317

start = time.time()

food_list = []
ingredient_list = []
seasoning_list = []
how_to_list = []
how_to_str = []
recipe_num_list = []
ingredient_name = []
ingredient_name_list = []

recipe_num = 6947317
check_num = 1;

req = requests.get("https://www.10000recipe.com/recipe/"+ str(recipe_num))
html = req.text       
bs = BeautifulSoup(html, 'html.parser')

num = 1;
while True:
    # 재료명 (유사도검사를 위한)
    d_ingredient_name = bs.select('#divConfirmedMaterialArea > ul:nth-of-type(2) > a:nth-of-type('+ str(num) +')')
    if not d_ingredient_name :
        break;
    num += 1;
    ingredient_name_str = [dom.text for dom in d_ingredient_name]
    ingredient_name_str = ''.join(ingredient_name_str).split()[0]
    ingredient_name.append(ingredient_name_str)
    ingredient_name_str = []

ingredient_name = ' '.join(ingredient_name)
ingredient_name_list.append(ingredient_name)
ingredient_name = []
print(ingredient_name_list)
# Out:
# ['간장 다진마늘 올리고당 참기름']
