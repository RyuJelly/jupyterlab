# %%
import pandas as pd

df1 = pd.read_csv('./output/최종레시피1.csv')
df2 = pd.read_csv('./output/최종레시피2.csv')
df3 = pd.read_csv('./output/최종레시피3.csv')
df4 = pd.read_csv('./output/최종레시피4.csv')
df5 = pd.read_csv('./output/최종레시피5.csv')
df6 = pd.read_csv('./output/최종레시피6.csv')

df = pd.concat([df1, df2, df3, df4, df5, df6])
df
# Out:
#                                                  name  \
# 0                           손쉽게 만드는 소불고기덮밥 레시피(불고기양념)
# 1     사과를 활용한 요리 / 프랑스 가정식 애플 클라푸티 ( apple Clafouti )
# 2                                 사과를 활용한 요리 / 사과 겉절이
# 3                                        # 당면활용, 당면만두
# 4                       보들한 무청이 더 맛있는 코다리조림, 무청 코다리조림
# ...                                               ...
# 9451                                끝물고추로 고추장아찌 담갔어요.
# 9452                            도라지 볶음, 명절 차례상 나물 만들기
# 9453              고기만두 김치만두 만두 속과 만두피 만들기 이글 하나면 오케이!
# 9454                                 두부조림 만들기 간단하니 굳!
# 9455                           스팸마요덮밥 만들기! 한그릇 뚝딱 했어요
#
#                                              ingredient  \
# 0            ['소불고기', '200g', '양파', '1/2개', '대파', '3개']
# 1     ['계란', '1개', '설탕', '30g', '우유', '80ml', '생크림',...
# 2     ['사과', '1개', '고춧가루', '1Ts', '액젓', '1Ts', '매실액'...
# 3     ['당면', '120g', '계란', '3개', '간장', '2스푼', '튀김가루'...
# ...

# %%
df.to_csv('./output/recipe.csv', index=False)
df = pd.read_csv('./output/recipe.csv')
df
# Out:
#                                                   name  \
# 0                            손쉽게 만드는 소불고기덮밥 레시피(불고기양념)
# 1      사과를 활용한 요리 / 프랑스 가정식 애플 클라푸티 ( apple Clafouti )
# 2                                  사과를 활용한 요리 / 사과 겉절이
# 3                                         # 당면활용, 당면만두
# 4                        보들한 무청이 더 맛있는 코다리조림, 무청 코다리조림
# ...                                                ...
# 67537                                끝물고추로 고추장아찌 담갔어요.
# 67538                            도라지 볶음, 명절 차례상 나물 만들기
# 67539              고기만두 김치만두 만두 속과 만두피 만들기 이글 하나면 오케이!
# 67540                                 두부조림 만들기 간단하니 굳!
# 67541                           스팸마요덮밥 만들기! 한그릇 뚝딱 했어요
#
#                                               ingredient  \
# 0             ['소불고기', '200g', '양파', '1/2개', '대파', '3개']
# 1      ['계란', '1개', '설탕', '30g', '우유', '80ml', '생크림',...
# 2      ['사과', '1개', '고춧가루', '1Ts', '액젓', '1Ts', '매실액'...
# 3      ['당면', '120g', '계란', '3개', '간장', '2스푼', '튀김가루'...
# ...
